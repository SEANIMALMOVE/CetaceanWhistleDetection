# %%
import os

# Data
import numpy as np
import pandas as pd

# Audio
import librosa
import librosa.display
from pydub import AudioSegment
import soundfile as sf

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# Deep Learning Visualization
from sklearn.metrics import confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import pandas as pd
#       7 # Audio
# ----> 8 import librosa
#       9 import librosa.display
#      10 from pydub import AudioSegment
#
# ModuleNotFoundError: No module named 'librosa'

# %% [markdown]
# ### Split Dataset
#
# Create train, validation and test datasets in 80%, 10% and 10% respectively.
# Also create classes dictionary to map the classes to integers, alphabetically sorted.

# %%
def split_dataset(df, train_size=0.8, val_size=0.1, test_size=0.1):
    # Split the dataset into training, validation and test sets
    df_train, df_val = train_test_split(df, test_size=1-train_size, random_state=42, stratify=df['Class'])
    df_val, df_test = train_test_split(df_val, test_size=(test_size/(val_size+test_size)), random_state=42, stratify=df_val['Class'])

    # Create classes mapping alphabetically
    classes = df['Class'].unique()
    classes.sort()
    classes_mapping = {classes[i]: i for i in range(len(classes))}
    # Reverse the classes_mapping dictionary
    reverse_classes_mapping = {v: k for k, v in classes_mapping.items()}

    df_train = df_train.sample(frac=1).reset_index(drop=True)
    df_val = df_val.sample(frac=1).reset_index(drop=True)
    df_test = df_test.sample(frac=1).reset_index(drop=True)

    return df_train, df_val, df_test, classes, classes_mapping, reverse_classes_mapping

def plot_split(df_train, df_val, df_test):
    # Combine the datasets with an additional column indicating the set
    df_train['Set'] = 'Train'
    df_val['Set'] = 'Validation'
    df_test['Set'] = 'Test'

    # Concatenate all dataframes
    df_combined = pd.concat([df_train, df_val, df_test])

    # Plot number of files per class in each set not stacked
    plt.figure(figsize=(14, 8))
    sns.countplot(data=df_combined, x='Class', hue='Set')
    plt.title('Number of Files per Class in Each Set')
    plt.xticks(rotation=90, ha='right', fontsize=10)  # Adjust fontsize and alignment
    plt.legend(title='Set')
    plt.tight_layout()  # Adjust layout to make room for labels
    plt.show()

# %% [markdown]
# ## Preprocess Audios

# %% [markdown]
# As most audios are 3 seconds more or less, the time windows that will be used will be 3 seconds
#
# Sampling rate was 256000 but BirdNET takes 48000, so 48000 will be used. It just changes the resolution of the audio.

# %%
# Function to preprocess audio
def preprocess_audio(file_path, target_sr=48000, duration=3):
    # Load audio
    signal, sr = librosa.load(file_path, sr=target_sr, mono=True)
    
    # Calculate the maximum length in samples and min length in samples
    max_length = target_sr * duration  # e.g., 48000 * 3
    min_length = target_sr * 1  # e.g., 48000 * 1
    
    # If the signal is shorter than the desired length, pad with silence
    if len(signal) <= max_length:
        padding = max_length - len(signal)
        pad_left = padding // 2
        pad_right = padding - pad_left
        signal = np.pad(signal, (pad_left, pad_right), mode='constant')
        return [signal]
    
    # If the signal is longer than the desired length, split into 3-second windows
    elif len(signal) > max_length:
        segments = []

        for start in range(0, len(signal), max_length):
            end = start + max_length
            segment = signal[start:end]
            # if min_length < len(segment) <= max_length:
            #     padding = max_length - len(segment)
            #     pad_left = padding // 2
            #     pad_right = padding - pad_left
            #     segment = np.pad(segment, (pad_left, pad_right), mode='constant')
                    
            segments.append(segment)
        return segments
    
    # If the signal is exactly the desired length, return as is
    else:
        return [signal]

# # Test preprocess on a single file
# sample_file = os.path.join(df_train["File"][0])
# processed_audios = preprocess_audio(sample_file, target_sr=48000, duration=3)

# # Visualize waveforms

# # print class
# print(f"Class: {df_train['Class'][0]}")

# processed_audio = processed_audios[0]
# plt.figure(figsize=(10, 4))
# librosa.display.waveshow(processed_audio, sr=48000)
# plt.title(f"Processed Audio Waveform")
# plt.show()

# # Mel spectrogram
# mel_spectrogram = librosa.feature.melspectrogram(y=processed_audio, sr=48000)
# mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

# # Visualize mel spectrogram
# plt.figure(figsize=(10, 4))
# librosa.display.specshow(mel_spectrogram, sr=48000, x_axis='time', y_axis='mel')
# plt.colorbar(format='%+2.0f dB')
# plt.title(f"Mel Spectrogram")
# plt.tight_layout()
# plt.show()

# # Listen audio
# import IPython.display as ipd
# ipd.Audio(processed_audio, rate=48000)

# %%
# # take 25 random samples of different classes and plot in a grid with its class
# # Select 25 random samples
# random_samples = df_train.sample(25, random_state=42)

# # Create a grid of plots
# fig, axes = plt.subplots(5, 5, figsize=(20, 20))

# # Flatten the axes
# axes = axes.ravel()

# # Loop through all the samples

# for i, (_, row) in enumerate(random_samples.iterrows()):
#     # Load the audio file
#     signal, sr = librosa.load(row['File'], sr=48000)

#     # preprocess the audio
#     processed_audios = preprocess_audio(row['File'], target_sr=48000, duration=3)
    
#     # Calculate the mel spectrogram
#     mel_spectrogram = librosa.feature.melspectrogram(y=processed_audios[0], sr=48000)
#     mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
    
#     # Plot the mel spectrogram
#     axes[i].imshow(mel_spectrogram, origin='lower')
#     axes[i].set_title(f"{row['Class']} ({classes_mapping[row['Class']]})")
#     axes[i].axis('off')

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Data Generators
#
# ## Data Augmentation

# %%
from pydub import AudioSegment

def add_noise(signal, noise_factor=0.005):
    noise = np.random.randn(len(signal))
    augmented_signal = signal + noise_factor * noise
    return augmented_signal

def shift_time(signal, shift_max=0.4):
    shift = np.random.randint(int(shift_max * len(signal)))
    augmented_signal = np.roll(signal, shift)
    return augmented_signal

# Mix Up
def mix_up(signal1, signal2, alpha=0.5):
    mixed_signal = alpha * signal1 + (1 - alpha) * signal2
    return mixed_signal

# %%
# # Check data augmentation in the same audio, plot the original and the augmented audio with each of the changes
# # Load the audio file
# sample_file = df_train['File'][0]
# sample_file_1 = df_train['File'][1]
# signal, sr = librosa.load(sample_file, sr=48000)
# signal_1, sr_1 = librosa.load(sample_file_1, sr=48000)

# # preprocess the audio
# signal = preprocess_audio(sample_file, target_sr=48000, duration=3)[0]
# signal_1 = preprocess_audio(sample_file_1, target_sr=48000, duration=3)[0]

# # Add noise
# augmented_signal_noise = add_noise(signal, noise_factor=0.005)

# # Shift time
# augmented_signal_shift = shift_time(signal, shift_max=0.2)

# # Mix up
# augmented_signal_mix_up = mix_up(signal, signal_1, alpha=0.5)

# # Mel spectrograms
# mel_spectrogram = librosa.feature.melspectrogram(y=signal, sr=48000)
# mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)

# mel_spectrogram_noise = librosa.feature.melspectrogram(y=augmented_signal_noise, sr=48000)
# mel_spectrogram_noise = librosa.power_to_db(mel_spectrogram_noise, ref=np.max)

# mel_spectrogram_shift = librosa.feature.melspectrogram(y=augmented_signal_shift, sr=48000)
# mel_spectrogram_shift = librosa.power_to_db(mel_spectrogram_shift, ref=np.max)

# mel_spectrogram_mix_up = librosa.feature.melspectrogram(y=augmented_signal_mix_up, sr=48000)
# mel_spectrogram_mix_up = librosa.power_to_db(mel_spectrogram_mix_up, ref=np.max)

# # Visualize mel spectrogram
# plt.figure(figsize=(40, 8))
# plt.subplot(1, 4, 1)
# librosa.display.specshow(mel_spectrogram, sr=48000, x_axis='time', y_axis='mel')
# plt.colorbar(format='%+2.0f dB')
# plt.title(f'Original ({df_train["Class"][0]})', fontsize=20)
# plt.tight_layout()

# plt.subplot(1, 4, 2)
# librosa.display.specshow(mel_spectrogram_noise, sr=48000, x_axis='time', y_axis='mel')
# plt.colorbar(format='%+2.0f dB')
# plt.title('Noise', fontsize=20)
# plt.tight_layout()

# plt.subplot(1, 4, 3)
# librosa.display.specshow(mel_spectrogram_shift, sr=48000, x_axis='time', y_axis='mel')
# plt.colorbar(format='%+2.0f dB')
# plt.title('Shift', fontsize=20)
# plt.tight_layout()

# plt.subplot(1, 4, 4)
# librosa.display.specshow(mel_spectrogram_mix_up, sr=48000, x_axis='time', y_axis='mel')
# plt.colorbar(format='%+2.0f dB')
# plt.title(f'Mix Up with {df_train["Class"][1]}', fontsize=20)
# plt.tight_layout()

# %% [markdown]
# # Dataset

# %% [markdown]
# ### Watkins Marine Mammals

# %%
df_wmm = pd.read_csv('../../Dataset/CSVs/WatkinsMarineMammals.csv')

# %%
df_wmm
# Out:
#                                                     File               Class  \
# 0      ../../Dataset/Audios/Watkins Marine Mammals/Wh...  White_sidedDolphin
# 1      ../../Dataset/Audios/Watkins Marine Mammals/Wh...  White_sidedDolphin
# 2      ../../Dataset/Audios/Watkins Marine Mammals/Wh...  White_sidedDolphin
# 3      ../../Dataset/Audios/Watkins Marine Mammals/Wh...  White_sidedDolphin
# 4      ../../Dataset/Audios/Watkins Marine Mammals/Wh...  White_sidedDolphin
# ...                                                  ...                 ...
# 15527  ../../Dataset/Audios/Watkins Marine Mammals/Ri...          RingedSeal
# 15528  ../../Dataset/Audios/Watkins Marine Mammals/Ri...          RingedSeal
# 15529  ../../Dataset/Audios/Watkins Marine Mammals/Ri...          RingedSeal
# 15530  ../../Dataset/Audios/Watkins Marine Mammals/Ri...          RingedSeal
# 15531  ../../Dataset/Audios/Watkins Marine Mammals/Ri...          RingedSeal
#
#        Duration
# 0      2.521905
# 1      2.069887
# 2      2.215329
# 3      2.742222
# 4      1.437052
# ...         ...
# 15527  0.458639
# 15528  0.334014
# 15529  1.418005
# 15530  0.773469
# 15531  0.117324
#
# [15532 rows x 3 columns]

# %%
# split wmm
df_train_wmm, df_val_wmm, df_test_wmm, CLASSES, CLASSES_MAPPING, REVERSE_CLASSES_MAPPING = split_dataset(df_wmm, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
df_train_wmm["Subset"] = "train"
df_val_wmm["Subset"] = "val"
df_test_wmm["Subset"] = "test"

df_wmm = pd.concat([df_train_wmm, df_val_wmm, df_test_wmm])

# %%
df_wmm["File"] = df_wmm["File"].str.replace("Watkins Marine Mammals/", "Watkins Marine Mammals/Full/")

# %%
df_wmm
# Out:
#                                                    File  \
# 0     ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 1     ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 2     ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 3     ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 4     ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# ...                                                 ...
# 2325  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 2326  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 2327  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 2328  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 2329  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
#
#                           Class   Duration Subset
# 0     PantropicalSpottedDolphin  37.747664  train
# 1                    SpermWhale   1.007211  train
# 2        Grampus_Risso'sDolphin   1.073469  train
# 3                SpinnerDolphin   0.185760  train
# 4     PantropicalSpottedDolphin   1.422313  train
# ...                         ...        ...    ...
# 2325               BowheadWhale   4.875011   test
# 2326     Grampus_Risso'sDolphin   0.585941   test
# 2327        White_beakedDolphin   1.412336   test
# 2328                KillerWhale   2.328707   test
# 2329               BowheadWhale   3.068844   test
#
# [15532 rows x 4 columns]

# %%
# reset index
df_wmm = df_wmm.reset_index(drop=True)

# %%
# open first element of the dataframe, check sample rate and duration and how the audio sounds
sample_file = df_wmm["File"][10]

signal, sr = librosa.load(sample_file, sr=None)
signal, sr
print("File path:" , sample_file)
print("Duration: ", len(signal) / sr)
print("Sample Rate: ", sr)
print("Class: ", df_wmm["Class"][10])

# Listen audio
import IPython.display as ipd
ipd.Audio(signal, rate=sr)
# Out:
# File path: ../../Dataset/Audios/Watkins Marine Mammals/Full/CommonDolphin/57026079.wav
# Duration:  2.5823
# Sample Rate:  40000
# Class:  CommonDolphin
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# For each file in the dataset, process the audio segmenting it in 3 seconds windows, if any of the segments is shorter, save it if it is at least 0.2 second long
# Create a new dataframe with the processed files maintaining original FilePath, Class, Subset, and Duration and include SegmentPath
processed_files = []

# target_sr = 48000
duration = 3

min_duration = 0.1

for _, row in df_wmm.iterrows():

    # Load audio
    file_path = row["File"]
    audio, audio_sr = librosa.load(file_path, sr=None)

    # get audio sample rate
    # print("Audio Sample Rate: ", audio_sr)
    # print("Audio Duration: ", len(audio) / audio_sr)
    # print("Audio Samples: ", len(audio))
    
    # Calculate the maximum length in samples and min length in samples
    max_length = audio_sr * duration  # e.g., 48000 * 3
    min_length = audio_sr * min_duration  # e.g., 48000 * 1
    
    # If the signal is shorter than the desired length, save
    if min_length <= len(audio) <= max_length:
        # start_sample = int(Fs * (row['StartSecond'] + 1))  # Convertir a muestras
        # end_sample = int(Fs * (row['EndSecond'] + 1))  # Convertir a muestras
        audio_class = row['Class']

        # Crear la carpeta para la clase
        class_folder = "../../Dataset/Audios/Watkins Marine Mammals/Segmented/" + audio_class
        os.makedirs(class_folder, exist_ok=True)

        end_second = len(audio) / audio_sr
        end_second = round(end_second, 2)

        # Guardar el segmento
        segment_path = row["File"].replace("Full", f"Segmented").replace(".wav", f"_0_{end_second}.wav")
        sf.write(segment_path, audio, audio_sr)

        processed_files.append({
            "FilePath": row["File"],
            "SegmentPath": segment_path,
            "Class": row["Class"],
            "Duration": len(audio) / audio_sr,
            "Origin": "Watkins Marine Mammals",
            "Subset": row["Subset"]
        })
    
    # If the signal is longer than the desired length, split into 3-second windows
    elif len(audio) > max_length:

        for start in range(0, len(audio), max_length):
            end = start + max_length
            segment = audio[start:end]
            
            if min_length <= len(segment) <= max_length:
            #     padding = max_length - len(segment)
            #     pad_left = padding // 2
            #     pad_right = padding - pad_left
            #     segment = np.pad(segment, (pad_left, pad_right), mode='constant')
            
                # Save segment in corresponding folder
                audio_class = row['Class']
                class_folder = "../../Dataset/Audios/Watkins Marine Mammals/Segmented/" + audio_class
                os.makedirs(class_folder, exist_ok=True)

                start_second = start / audio_sr
                end_second = end / audio_sr

                # round to 2 decimal places
                end_second = round(end_second, 2)

                segment_path = row["File"].replace("Full", f"Segmented").replace(".wav", f"_{start_second}_{end_second}.wav")
                # save segment in folder
                sf.write(segment_path, segment, audio_sr)

                processed_files.append({
                    "FilePath": row["File"],
                    "SegmentPath": segment_path,
                    "Class": row["Class"],
                    "Duration": len(segment) / audio_sr,
                    "Origin": "Watkins Marine Mammals",
                    "Subset": row["Subset"]
                })

df_processed_wmm = pd.DataFrame(processed_files)

# save as CSV in CSV folder
df_processed_wmm.to_csv("../../Dataset/CSVs/Datasets/WatkinsMarineMammalsSegmented.csv", index=False)

# print(len(df_processed_wmm))

# %%
df_processed_wmm
# Out:
#                                                 FilePath  \
# 0      ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 1      ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 2      ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 3      ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 4      ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# ...                                                  ...
# 43588  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 43589  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 43590  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 43591  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
# 43592  ../../Dataset/Audios/Watkins Marine Mammals/Fu...
#
#                                              SegmentPath  \
# 0      ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 1      ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 2      ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 3      ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 4      ../../Dataset/Audios/Watkins Marine Mammals/Se...
# ...                                                  ...
# 43588  ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 43589  ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 43590  ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 43591  ../../Dataset/Audios/Watkins Marine Mammals/Se...
# 43592  ../../Dataset/Audios/Watkins Marine Mammals/Se...
#
#                            Class  Duration                  Origin Subset
# 0      PantropicalSpottedDolphin  3.000000  Watkins Marine Mammals  train
# 1      PantropicalSpottedDolphin  3.000000  Watkins Marine Mammals  train
# 2      PantropicalSpottedDolphin  3.000000  Watkins Marine Mammals  train
# 3      PantropicalSpottedDolphin  3.000000  Watkins Marine Mammals  train
# 4      PantropicalSpottedDolphin  3.000000  Watkins Marine Mammals  train
# ...                          ...       ...                     ...    ...
# 43588               BowheadWhale  1.875000  Watkins Marine Mammals   test
# 43589     Grampus_Risso'sDolphin  0.585938  Watkins Marine Mammals   test
# 43590        White_beakedDolphin  1.412300  Watkins Marine Mammals   test
# 43591                KillerWhale  2.328676  Watkins Marine Mammals   test
# 43592               BowheadWhale  3.000000  Watkins Marine Mammals   test
#
# [43593 rows x 6 columns]

# %%
df_wmm = df_processed_wmm

# %%
# Take only classes: BottlenoseDolphin, 'BowheadWhale', 'CommonDolphin', 'Fin_FinbackWhale', "Grampus_Risso'sDolphin, 'HarborPorpoise, 'HumpbackWhale, 'KillerWhale, 'Long_FinnedPilotWhale', 'MinkeWhale, 'Rough_ToothedDolphin', 'SpermWhale, 'StripedDolphin'
df_wmm = df_wmm[df_wmm['Class'].isin(['BottlenoseDolphin', 'CommonDolphin', 'Fin_FinbackWhale', "Grampus_Risso'sDolphin", 'HarborPorpoise', 'HumpbackWhale', 'KillerWhale', 'Long_FinnedPilotWhale', 'MinkeWhale', 'SpermWhale', 'StripedDolphin'])]
df_wmm = df_wmm.reset_index(drop=True)

# %%
# take 1000 random samples per class as maximum
df_wmm = df_wmm.groupby("Class").apply(lambda x: x.sample(n=min(1000, x.shape[0]), random_state=42)).reset_index(drop=True)
# Out:
# /tmp/ipykernel_3898145/2827012017.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_wmm = df_wmm.groupby("Class").apply(lambda x: x.sample(n=min(1000, x.shape[0]), random_state=42)).reset_index(drop=True)

# %%
# plot split by Subset in df_wmm
plt.figure(figsize=(14, 8))
sns.countplot(data=df_wmm, x='Class', hue='Subset')
plt.title('Number of Files per Class in Each Set')
plt.xticks(rotation=90, ha='right', fontsize=10)  # Adjust fontsize and alignment
plt.legend(title='Set')
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()

# %% [markdown]
# ### Neus - Marine Mammals

# %%
# Main Folder with all classes and files
main_folder = '../../Dataset/Audios/Neus/Marine Mammals/'

# Folder contains subfolders = classes and in them, the audio sample
classes = os.listdir(main_folder)

# remove folder Segmented
# classes.remove('Segmented')

# delete README.MD
# classes.remove('README.MD')

# Create an empty list to store the audio file paths
audio_files = []

# Loop through all the subfolders and files
for subfolder in classes:
    # Get the list of all files in the subfolder
    files = os.listdir(main_folder + subfolder)
    # Loop through all the files
    for f in files:
        # Get the full path of the file
        audio_files.append(main_folder + subfolder + '/' + f)

df_neus_mm = pd.DataFrame(audio_files, columns=['File'])

# Add class
df_neus_mm['Class'] = df_neus_mm['File'].apply(lambda x: x.split('/')[-2])

# Number of files per class and duration of each file
for f in audio_files:
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_neus_mm.loc[df_neus_mm['File'] == f, 'Duration'] = duration

# If Class Dd then CommonDolphin, Gm then Grampus_Risso'sDolphin, Hb then HumpbackWhale, Kk then KillerWhale, Lf then Long_FinnedPilotWhale, Mw then MinkeWhale, Rt then Rough_ToothedDolphin, Sw then SpermWhale, Sd then StripedDolphin
# df_neus_mm['Class'] = df_neus_mm['Class'].apply(lambda x: 'CommonDolphin' if x == 'Dd' else x)
# df_neus_mm['Class'] = df_neus_mm['Class'].apply(lambda x: "Long_FinnedPilotWhale" if x == 'Gm' else x)
# df_neus_mm['Class'] = df_neus_mm['Class'].apply(lambda x: 'KillerWhale' if x == 'Oo' else x)
# df_neus_mm['Class'] = df_neus_mm['Class'].apply(lambda x: 'SpermWhale' if x == 'Pm' else x)
# df_neus_mm['Class'] = df_neus_mm['Class'].apply(lambda x: 'StripedDolphin' if x == 'Sc' else x)

# %%
df_neus_mm
# Out:
#                                                    File           Class  \
# 0     ../../Dataset/Audios/Neus/Segmented/Background...      Background
# 1     ../../Dataset/Audios/Neus/Segmented/Background...      Background
# 2     ../../Dataset/Audios/Neus/Segmented/Background...      Background
# 3     ../../Dataset/Audios/Neus/Segmented/Background...      Background
# 4     ../../Dataset/Audios/Neus/Segmented/Background...      Background
# ...                                                 ...             ...
# 1203  ../../Dataset/Audios/Neus/Segmented/StripedDol...  StripedDolphin
# 1204  ../../Dataset/Audios/Neus/Segmented/StripedDol...  StripedDolphin
# 1205  ../../Dataset/Audios/Neus/Segmented/StripedDol...  StripedDolphin
# 1206  ../../Dataset/Audios/Neus/Segmented/StripedDol...  StripedDolphin
# 1207  ../../Dataset/Audios/Neus/Segmented/StripedDol...  StripedDolphin
#
#       Duration
# 0     3.000000
# 1     3.000000
# 2     3.000000
# 3     3.000000
# 4     3.000000
# ...        ...
# 1203  2.569524
# 1204  2.710839
# 1205  1.459093
# 1206  0.454240
# 1207  2.813605
#
# [1208 rows x 3 columns]

# %%
df_neus_mm = df_neus_mm[df_neus_mm['Class'] != 'Background']
df_neus_mm.reset_index(drop=True, inplace=True)
df_neus_mm
# Out:
#                                                   File                  Class  \
# 0    ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# 1    ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# 2    ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# 3    ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# 4    ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# ..                                                 ...                    ...
# 753  ../../Dataset/Audios/Neus/Segmented/StripedDol...         StripedDolphin
# 754  ../../Dataset/Audios/Neus/Segmented/StripedDol...         StripedDolphin
# 755  ../../Dataset/Audios/Neus/Segmented/StripedDol...         StripedDolphin
# 756  ../../Dataset/Audios/Neus/Segmented/StripedDol...         StripedDolphin
# 757  ../../Dataset/Audios/Neus/Segmented/StripedDol...         StripedDolphin
#
#      Duration
# 0    1.334875
# 1    0.195374
# 2    1.903628
# 3    0.216372
# 4    0.418549
# ..        ...
# 753  2.569524
# 754  2.710839
# 755  1.459093
# 756  0.454240
# 757  2.813605
#
# [758 rows x 3 columns]

# %%
# row with KillerWhale extract
df_KW = df_neus_mm[df_neus_mm['Class'] == 'KillerWhale'] # 1 audio
# row with SpermWhale extract
df_SW = df_neus_mm[df_neus_mm['Class'] == 'SpermWhale'] # 2 audios
# row with StripDolphin extract
df_SD = df_neus_mm[df_neus_mm['Class'] == 'StripedDolphin'] # 1 audio

# df_neus is all but the 3 classes
df_neus_mm = df_neus_mm[~df_neus_mm['Class'].isin(['KillerWhale', 'SpermWhale', 'StripedDolphin'])]

# %%
# split neus
df_train_neus, df_val_neus, df_test_neus_mm, _, _, _ = split_dataset(df_neus_mm, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
# add KillerWhale and StripedDolphin to train
df_train_neus = pd.concat([df_train_neus, df_KW, df_SD])
# Split SpermWhale in half for train and validation
df_train_neus = pd.concat([df_train_neus, df_SW.iloc[:1]])
df_val_neus = pd.concat([df_val_neus, df_SW.iloc[1:]])

# %%
df_train_neus["Subset"] = "train"
df_val_neus["Subset"] = "val"
df_test_neus_mm["Subset"] = "test"

df_neus_mm = pd.concat([df_train_neus, df_val_neus, df_test_neus_mm])

# %%
df_neus_mm
# Out:
#                                                   File                  Class  \
# 0    ../../Dataset/Audios/Neus/Segmented/KillerWhal...            KillerWhale
# 1    ../../Dataset/Audios/Neus/Segmented/KillerWhal...            KillerWhale
# 2    ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# 3    ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# 4    ../../Dataset/Audios/Neus/Segmented/CommonDolp...          CommonDolphin
# ..                                                 ...                    ...
# 109  ../../Dataset/Audios/Neus/Segmented/KillerWhal...            KillerWhale
# 110  ../../Dataset/Audios/Neus/Segmented/Long_Finne...  Long_FinnedPilotWhale
# 111  ../../Dataset/Audios/Neus/Segmented/KillerWhal...            KillerWhale
# 112  ../../Dataset/Audios/Neus/Segmented/KillerWhal...            KillerWhale
# 113  ../../Dataset/Audios/Neus/Segmented/KillerWhal...            KillerWhale
#
#      Duration Subset
# 0    1.372426  train
# 1    0.149342  train
# 2    0.893152  train
# 3    1.363084  train
# 4    0.331837  train
# ..        ...    ...
# 109  2.441406   test
# 110  0.855465   test
# 111  1.379501   test
# 112  1.929206   test
# 113  0.412472   test
#
# [758 rows x 4 columns]

# %%
# File is FilePath
df_neus_mm.rename(columns={"File": "FilePath"}, inplace=True)
df_neus_mm["SegmentPath"] = df_neus_mm["FilePath"]
df_neus_mm["Origin"] = "Neus Marine Mammals"

# resort columns: filepath, segmentpath, class, duration, origin, subset
df_neus_mm = df_neus_mm[['FilePath', 'SegmentPath', 'Class', 'Duration', 'Origin', 'Subset']]
#save as CSV in CSV folder
df_neus_mm.to_csv("../../Dataset/CSVs/Datasets/NeusMarineMammalsSegmented.csv", index=False)

# %%
# For each file in the dataset, process the audio segmenting it in 3 seconds windows, if any of the segments is shorter, save it if it is at least 0.2 second long
# Create a new dataframe with the processed files maintaining original FilePath, Class, Subset, and Duration and include SegmentPath
processed_files = []

# target_sr = 48000
duration = 3

min_duration = 2

for _, row in df_neus_mm.iterrows():

    # Load audio
    file_path = row["File"]
    audio, audio_sr = librosa.load(file_path, sr=None)

    # print("Audio Sample Rate: ", audio_sr)
    # print("Audio Duration: ", len(audio) / audio_sr)
    # print("Audio Samples: ", len(audio))
    
    # Calculate the maximum length in samples and min length in samples
    max_length = audio_sr * duration  # e.g., 48000 * 3
    min_length = audio_sr * min_duration  # e.g., 48000 * 1
    
    # If the signal is shorter than the desired length, save
    if min_length <= len(audio) <= max_length:
        # start_sample = int(Fs * (row['StartSecond'] + 1))  # Convertir a muestras
        # end_sample = int(Fs * (row['EndSecond'] + 1))  # Convertir a muestras
        audio_class = row['Class']

        # Crear la carpeta para la clase
        class_folder = "../../Dataset/Audios/Neus/Segmented/" + audio_class
        os.makedirs(class_folder, exist_ok=True)

        end_second = len(audio) / audio_sr
        end_second = round(end_second, 2)

        # Guardar el segmento
        segment_path = row["File"].split("Neus")[0] + "Neus/Segmented/" + audio_class + "/"	
        base_filename = os.path.basename(row["File"])
        segment_path += base_filename.replace(".wav", f"_0_{end_second}.wav")
        sf.write(segment_path, audio, audio_sr)

        processed_files.append({
            "FilePath": row["File"],
            "SegmentPath": segment_path,
            "Class": row["Class"],
            "Duration": len(audio) / audio_sr,
            "Origin": "Neus Marine Mammals",
            "Subset": row["Subset"]
        })
    
    # If the signal is longer than the desired length, split into 3-second windows
    elif len(audio) > max_length:

        for start in range(0, len(audio), max_length):
            end = start + max_length
            segment = audio[start:end]
            
            if min_length <= len(segment) <= max_length:
            #     padding = max_length - len(segment)
            #     pad_left = padding // 2
            #     pad_right = padding - pad_left
            #     segment = np.pad(segment, (pad_left, pad_right), mode='constant')
            
                # Save segment in corresponding folder
                audio_class = row['Class']
                class_folder = "../../Dataset/Audios/Neus/Segmented/" + audio_class
                os.makedirs(class_folder, exist_ok=True)

                start_second = start / audio_sr
                end_second = end / audio_sr

                # round to 2 decimal places
                end_second = round(end_second, 2)

                segment_path = row["File"].split("Neus")[0] + "Neus/Segmented/" + audio_class + "/"
                base_filename = os.path.basename(row["File"])
                segment_path += base_filename.replace(".wav", f"_{start_second}_{end_second}.wav")
                sf.write(segment_path, segment, audio_sr)

                processed_files.append({
                    "FilePath": row["File"],
                    "SegmentPath": segment_path,
                    "Class": row["Class"],
                    "Duration": len(segment) / audio_sr,
                    "Origin": "Neus Marine Mammals",
                    "Subset": row["Subset"]
                })

    else:
        # print audio not processed, sample rate, samples, and duration in seconds
        print("Audio not processed: ", row["File"])
        print("Sample Rate: ", audio_sr)
        print("Samples: ", len(audio))
        print("Duration: ", len(audio) / audio_sr)
        print("===========================")

df_processed_neus = pd.DataFrame(processed_files)

# save as CSV in CSV folder
df_processed_neus.to_csv("../../Dataset/CSVs/Datasets/NeusMarineMammalsSegmented.csv", index=False)

# print(len(df_processed_wmm))

# %%
# sum duration of not segmented files
df_neus_mm["Duration"].sum()
# Out:
# 10097.45746031746

# %%
# sum duration of processed files
df_processed_neus["Duration"].sum()
# Out:
# 10090.157712585034

# %% [markdown]
# ### SEANIMALMOVE - Background (no clicks, no whistles)

# %%
# Load CSV
df_sam_background = pd.read_csv('../../Dataset/CSVs/DatasetMultiLabel3.csv')
# Insert in path ../../Dataset/Audios/SEANIMALMOVE/SegmentedAudiosMultiLabel3/{Path}
df_sam_background['File'] = df_sam_background['SegmentPath'].apply(lambda x: f"../../Dataset/Audios/SEANIMALMOVE/SegmentedAudiosMultiLabel3/{x}")
# Take only rows where NumClasses = 0
# df_sam_background = df_sam_background[df_sam_background['NumClasses'] == 0]

# Take only rows where Class list does not contains CLICK, Whistle,Batida,BatidaClicks or BatidaClicksRapidaCascabel
df_sam_background = df_sam_background[~df_sam_background['Class'].str.contains('CLICK|Whistle|Batida|BatidaClicks|BatidaClicksRapidaCascabelEmbarcacionLejana|EmbarcacionCercana,')]
df_sam_background_empty = df_sam_background[df_sam_background['NumClasses'] == 0]
df_sam_background = df_sam_background[df_sam_background['NumClasses'] > 0]
# Take 1000 random samples of the background
df_sam_background = df_sam_background.sample(min(5000, len(df_sam_background)), random_state=42).reset_index(drop=True)
df_sam_background_empty = df_sam_background_empty.sample(min(len(df_sam_background), len(df_sam_background_empty)), random_state=42).reset_index(drop=True)
df_sam_background = pd.concat([df_sam_background, df_sam_background_empty])
# Create Column Duration and set all to 3
df_sam_background['Duration'] = 3
# Keep only columns Path, Class and Duration
df_sam_background = df_sam_background[['File', 'Class', 'Duration']]
# Class column value = Background
df_sam_background['Class'] = 'Background'

# %%
# Rename column File as FilePath
df_sam_background = df_sam_background.rename(columns={'File': 'FilePath'})
df_sam_background["SegmentPath"] = df_sam_background["FilePath"]
df_sam_background["Origin"] = "SEANIMALMOVE"

# %%
df_train_bg, df_val_bg, df_test_sam_bg, _, _, _ = split_dataset(df_sam_background, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
df_train_bg["Subset"] = "train"
df_val_bg["Subset"] = "val"
df_test_sam_bg["Subset"] = "test"

df_sam_background = pd.concat([df_train_bg, df_val_bg, df_test_sam_bg])

# %%
# resort columns: FilePath,SegmentPath,Class,Duration,Origin,Subset
df_sam_background = df_sam_background[['FilePath', 'SegmentPath', 'Class', 'Duration', 'Origin', 'Subset']]
# save csv in CSVs dataset folder
df_sam_background.to_csv("../../Dataset/CSVs/Datasets/SEANIMALMOVEBackgroundSegmented.csv", index=False)

# %% [markdown]
# ### Neus - Background (Anthropogenic, ferries)

# %%
# Background ferries
# Read all audio files in the input folder and its subfolders and set them as class Background
# Main Folder with all classes and files
main_folder = '../../Dataset/Audios/Neus/Anthropogenic/'

# Look for any .wav file in the folder or any subfolder
audio_files = []
for root, _, files in os.walk(main_folder):
    for file in files:
        if file.endswith('.wav'):
            audio_files.append(os.path.join(root, file))

df_bg_ff_neus = pd.DataFrame(audio_files, columns=['File'])

# Add class
df_bg_ff_neus['Class'] = "Background"
# total_duration = 0
# Number of files per class and duration of each file
for f in audio_files:
    
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_bg_ff_neus.loc[df_bg_ff_neus['File'] == f, 'Duration'] = duration
    # total_duration += duration

# # Take half of the files by randomness
# df_bg_ff_neus = df_bg_ff_neus.sample(len(df_bg_ff_neus) // 2, random_state=42).reset_index(drop=True)

# %%
df_bg_ff_neus
# Out:
#                                                  File       Class    Duration
# 0   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background  140.839819
# 1   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background  136.264898
# 2   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background  120.102313
# 3   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background  151.027982
# 4   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.424490
# 5   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.505125
# 6   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.391293
# 7   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.561814
# 8   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.416780
# 9   ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   12.773016
# 10  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.846259
# 11  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   22.400771
# 12  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.917052
# 13  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.516327
# 14  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   23.320771
# 15  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   19.381814
# 16  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.708209
# 17  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   11.606395
# 18  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.408435
# 19  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.491429
# 20  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   21.119773
# 21  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.475737
# 22  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   14.497823
# 23  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.510023
# 24  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   21.592200
# 25  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   26.699410
# 26  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   24.089569
# 27  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.450567
# 28  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   21.956599
# 29  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.479229
# 30  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   21.781905
# 31  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.586667
# 32  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.672472
# 33  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.538050
# 34  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.480544
# 35  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.749977
# 36  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.528753
# 37  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.523673
# 38  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.894422
# 39  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.403764
# 40  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.214376
# 41  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   21.144490
# 42  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.558549
# 43  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.460363
# 44  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.537234
# 45  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.661950
# 46  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   20.534195
# 47  ../../Dataset/Audios/Neus/Anthropogenic/Regist...  Background   21.567438

# %%
# Split background
df_train_bg_ff_neus, df_val_bg_ff_neus, df_test_bg_ff_neus, _, _, _ = split_dataset(df_bg_ff_neus, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
df_train_bg_ff_neus["Subset"] = "train"
df_val_bg_ff_neus["Subset"] = "val"
df_test_bg_ff_neus["Subset"] = "test"

df_bg_ff_neus = pd.concat([df_train_bg_ff_neus, df_val_bg_ff_neus, df_test_bg_ff_neus])

# %%
# For each file in the dataset, process the audio segmenting it in 3 seconds windows, if any of the segments is shorter, save it if it is at least 0.2 second long
# Create a new dataframe with the processed files maintaining original FilePath, Class, Subset, and Duration and include SegmentPath
processed_files = []

# target_sr = 48000
duration = 3

min_duration = 3

audio_class = "Background"

for _, row in df_bg_ff_neus.iterrows():

    # Load audio
    file_path = row["File"]
    audio, audio_sr = librosa.load(file_path, sr=None)

    # print("Audio Sample Rate: ", audio_sr)
    # print("Audio Duration: ", len(audio) / audio_sr)
    # print("Audio Samples: ", len(audio))
    
    # Calculate the maximum length in samples and min length in samples
    max_length = audio_sr * duration  # e.g., 48000 * 3
    min_length = audio_sr * min_duration  # e.g., 48000 * 1
    
    # If the signal is shorter than the desired length, save
    if min_length <= len(audio) <= max_length:
        # start_sample = int(Fs * (row['StartSecond'] + 1))  # Convertir a muestras
        # end_sample = int(Fs * (row['EndSecond'] + 1))  # Convertir a muestras

        # Crear la carpeta para la clase
        class_folder = "../../Dataset/Audios/Neus/Segmented/" + audio_class
        os.makedirs(class_folder, exist_ok=True)

        end_second = len(audio) / audio_sr
        end_second = round(end_second, 2)

        # Guardar el segmento
        segment_path = row["File"].split("Neus")[0] + "Neus/Segmented/" + audio_class + "/"	
        base_filename = os.path.basename(row["File"])
        segment_path += base_filename.replace(".wav", f"_0_{end_second}.wav")
        sf.write(segment_path, audio, audio_sr)

        processed_files.append({
            "FilePath": row["File"],
            "SegmentPath": segment_path,
            "Class": row["Class"],
            "Duration": len(audio) / audio_sr,
            "Origin": "Neus Background Fast Ferries",
            "Subset": row["Subset"]
        })
    
    # If the signal is longer than the desired length, split into 3-second windows
    elif len(audio) > max_length:

        for start in range(0, len(audio), max_length):
            end = start + max_length
            segment = audio[start:end]
            
            if min_length <= len(segment) <= max_length:
            #     padding = max_length - len(segment)
            #     pad_left = padding // 2
            #     pad_right = padding - pad_left
            #     segment = np.pad(segment, (pad_left, pad_right), mode='constant')
            
                # Save segment in corresponding folder
                # audio_class = row['Class']
                class_folder = "../../Dataset/Audios/Neus/Segmented/" + audio_class
                os.makedirs(class_folder, exist_ok=True)

                start_second = start / audio_sr
                end_second = end / audio_sr

                # round to 2 decimal places
                end_second = round(end_second, 2)

                segment_path = row["File"].split("Neus")[0] + "Neus/Segmented/" + audio_class + "/"
                base_filename = os.path.basename(row["File"])
                segment_path += base_filename.replace(".wav", f"_{start_second}_{end_second}.wav")
                # print(segment_path)
                sf.write(segment_path, segment, audio_sr)

                processed_files.append({
                    "FilePath": row["File"],
                    "SegmentPath": segment_path,
                    "Class": row["Class"],
                    "Duration": len(segment) / audio_sr,
                    "Origin": "Neus Background Fast Ferries",
                    "Subset": row["Subset"]
                })

df_processed_neus = pd.DataFrame(processed_files)

# save as CSV in CSV folder
df_processed_neus.to_csv("../../Dataset/CSVs/Datasets/NeusBackgroundFastFerries.csv", index=False)

# print(len(df_processed_wmm))
# Out:
# ../../Dataset/Audios/Neus/Segmented/Background/ferry16_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry16_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry16_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry16_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry16_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry16_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry26_21.0_24.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry3_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry3_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry3_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry3_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry38_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry38_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry38_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry38_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry38_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry38_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry9_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry9_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry9_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry9_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry9_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry9_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry1_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry1_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry1_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry1_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry1_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry1_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry25_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry25_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry25_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry25_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry25_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry25_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry31_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry31_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry31_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry31_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry31_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry31_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry21_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry21_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry21_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry21_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry21_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry21_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry35_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry35_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry35_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry35_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry35_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry35_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry23_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry23_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry23_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry23_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry23_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry23_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry23_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry10_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry10_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry10_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry10_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry10_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry10_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_21.0_24.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_24.0_27.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_27.0_30.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_30.0_33.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_33.0_36.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_36.0_39.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_39.0_42.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_42.0_45.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_45.0_48.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_48.0_51.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_51.0_54.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_54.0_57.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_57.0_60.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_60.0_63.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_63.0_66.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_66.0_69.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_69.0_72.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_72.0_75.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_75.0_78.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_78.0_81.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_81.0_84.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_84.0_87.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_87.0_90.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_90.0_93.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_93.0_96.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_96.0_99.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_99.0_102.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_102.0_105.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_105.0_108.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_108.0_111.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_111.0_114.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_114.0_117.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_117.0_120.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_120.0_123.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_123.0_126.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_126.0_129.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_129.0_132.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_132.0_135.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comarit100m20nudos_135.0_138.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_21.0_24.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_24.0_27.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_27.0_30.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_30.0_33.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_33.0_36.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_36.0_39.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_39.0_42.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_42.0_45.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_45.0_48.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_48.0_51.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_51.0_54.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_54.0_57.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_57.0_60.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_60.0_63.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_63.0_66.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_66.0_69.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_69.0_72.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_72.0_75.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_75.0_78.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_78.0_81.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_81.0_84.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_84.0_87.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_87.0_90.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_90.0_93.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_93.0_96.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_96.0_99.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_99.0_102.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_102.0_105.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_105.0_108.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_108.0_111.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_111.0_114.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_114.0_117.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_117.0_120.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_120.0_123.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_123.0_126.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_126.0_129.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_129.0_132.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoToledoSpiryt120m19nudoswav_132.0_135.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry27_21.0_24.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry5_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry5_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry5_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry5_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry5_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry5_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry5_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry13_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry13_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry13_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry13_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry13_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry13_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry13_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry22_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry22_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry22_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry22_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry22_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry22_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry34_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry34_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry34_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry34_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry34_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry34_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry7_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry7_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry7_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry7_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry7_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry7_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_21.0_24.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_24.0_27.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_27.0_30.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_30.0_33.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_33.0_36.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_36.0_39.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_39.0_42.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_42.0_45.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_45.0_48.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_48.0_51.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_51.0_54.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_54.0_57.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_57.0_60.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_60.0_63.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_63.0_66.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_66.0_69.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_69.0_72.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_72.0_75.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_75.0_78.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_78.0_81.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_81.0_84.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_84.0_87.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_87.0_90.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_90.0_93.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_93.0_96.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_96.0_99.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_99.0_102.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_102.0_105.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_105.0_108.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_108.0_111.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_111.0_114.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_114.0_117.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_117.0_120.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_120.0_123.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_123.0_126.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_126.0_129.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_129.0_132.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_132.0_135.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_135.0_138.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_138.0_141.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_141.0_144.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_144.0_147.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/cargoFreyna55m15nudoswav_147.0_150.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry24_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry24_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry24_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry30_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry30_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry30_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry30_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry30_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry30_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry43_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry43_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry43_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry43_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry43_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry43_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry44_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry44_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry44_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry44_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry44_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry44_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry11_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry11_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry11_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry11_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry11_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry11_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry4_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry4_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry4_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry4_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry4_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry4_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry12_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry12_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry12_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry12_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry12_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry12_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry6_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry6_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry6_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry6_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry6_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry6_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry42_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry42_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry42_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry42_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry42_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry42_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry33_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry33_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry33_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry33_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry33_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry33_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry36_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry36_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry36_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry36_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry36_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry36_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry32_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry32_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry32_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry32_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry32_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry32_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry45_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry45_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry45_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry45_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry29_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry29_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry29_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry29_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry29_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry29_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry2_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry2_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry2_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry2_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry2_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry2_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry37_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry37_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry37_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry37_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry37_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry37_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry37_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry40_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry40_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry40_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry40_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry40_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry40_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_21.0_24.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_24.0_27.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_27.0_30.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_30.0_33.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_33.0_36.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_36.0_39.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_39.0_42.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_42.0_45.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_45.0_48.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_48.0_51.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_51.0_54.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_54.0_57.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_57.0_60.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_60.0_63.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_63.0_66.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_66.0_69.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_69.0_72.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_72.0_75.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_75.0_78.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_78.0_81.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_81.0_84.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_84.0_87.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_87.0_90.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_90.0_93.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_93.0_96.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_96.0_99.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_99.0_102.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_102.0_105.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_105.0_108.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_108.0_111.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_111.0_114.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_114.0_117.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/Comanav70m22nudos_117.0_120.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry14_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry14_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry14_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry14_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry14_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry14_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry14_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry20_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry20_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry20_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry20_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry20_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry20_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry20_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry19_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry19_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry19_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry19_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry19_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry19_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry19_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry28_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry28_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry28_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry28_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry28_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry28_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry39_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry39_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry39_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry39_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry39_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry39_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry17_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry17_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry17_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry17_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry17_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry17_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry41_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry41_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry41_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry41_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry41_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry41_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry41_18.0_21.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry18_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry18_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry18_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry18_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry18_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry18_15.0_18.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry8_0.0_3.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry8_3.0_6.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry8_6.0_9.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry8_9.0_12.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry8_12.0_15.0.wav
# ../../Dataset/Audios/Neus/Segmented/Background/ferry8_15.0_18.0.wav

# %% [markdown]
# ### SEANIMALMOVE - Background (Anthropogenic, ferries, divers... from WOPAM Day)

# %%
# Background ferries
# Read all audio files in the input folder and its subfolders and set them as class Background
# Main Folder with all classes and files
audio_files = []

main_folder = '../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/'

classes = os.listdir(main_folder)

# Loop through all the subfolders and files
for subfolder in classes:
    # Get the list of all files in the subfolder
    files = os.listdir(main_folder + subfolder)
    # Loop through all the files
    for f in files:
        # Get the full path of the file
        audio_files.append(main_folder + subfolder + '/' + f)

df_bg_seanimalmove_wopam = pd.DataFrame(audio_files, columns=['File'])

# Add class
# df_bg_seanimalmove_wopam['Class'] = "Background"
# total_duration = 0
# Number of files per class and duration of each file

df_bg_seanimalmove_wopam['Class'] = df_bg_seanimalmove_wopam['File'].apply(lambda x: x.split('/')[-2])

for f in audio_files:
    
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_bg_seanimalmove_wopam.loc[df_bg_seanimalmove_wopam['File'] == f, 'Duration'] = duration
    # total_duration += duration

# %%
df_bg_seanimalmove_wopam
# Out:
#                                                   File                 Class  \
# 0    ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Hum...  Human_diver_1_breath
# 1    ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Hum...  Human_diver_1_breath
# 2    ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Hum...  Human_diver_1_breath
# 3    ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Hum...  Human_diver_1_breath
# 4    ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Hum...  Human_diver_1_breath
# ..                                                 ...                   ...
# 145  ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Mot...            Motor_boat
# 146  ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Mot...            Motor_boat
# 147  ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Mot...            Motor_boat
# 148  ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Mot...            Motor_boat
# 149  ../../Dataset/Audios/SEANIMALMOVE/WOPAMDay/Mot...            Motor_boat
#
#      Duration
# 0         3.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
# ..        ...
# 145       3.0
# 146       3.0
# 147       3.0
# 148       3.0
# 149       3.0
#
# [150 rows x 3 columns]

# %%
# class Human_diver_1_breath and Human_diver_2_wee are Human_diver
df_bg_seanimalmove_wopam['Class'] = df_bg_seanimalmove_wopam['Class'].apply(lambda x: 'Human_diver' if x in ['Human_diver_1_breath', 'Human_diver_2_wee'] else x)

# %%
# Split background
df_train_bg_seanimalmove_wopam, df_val_bg_seanimalmove_wopam, df_test_bg_seanimalmove_wopam, _, _, _ = split_dataset(df_bg_seanimalmove_wopam, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
df_train_bg_seanimalmove_wopam["Subset"] = "train"
df_val_bg_seanimalmove_wopam["Subset"] = "val"
df_test_bg_seanimalmove_wopam["Subset"] = "test"

df_bg_seanimalmove_wopam = pd.concat([df_train_bg_seanimalmove_wopam, df_val_bg_seanimalmove_wopam, df_test_bg_seanimalmove_wopam])

# %%
# For each file in the dataset, process the audio segmenting it in 3 seconds windows, if any of the segments is shorter, save it if it is at least 0.2 second long
# Create a new dataframe with the processed files maintaining original FilePath, Class, Subset, and Duration and include SegmentPath
processed_files = []

# target_sr = 48000
duration = 3

min_duration = 3

for _, row in df_bg_seanimalmove_wopam.iterrows():

    # Load audio
    file_path = row["File"]

    # print("Audio Sample Rate: ", audio_sr)
    # print("Audio Duration: ", len(audio) / audio_sr)
    # print("Audio Samples: ", len(audio))
    

    processed_files.append({
        "FilePath": file_path,
        "SegmentPath": file_path,
        "Class": row["Class"],
        "Duration": 3,
        "Origin": "SEANIMALMOVE Background WOPAM Day",
        "Subset": row["Subset"]
    })
    

df_processed_neus = pd.DataFrame(processed_files)

# save as CSV in CSV folder
df_processed_neus.to_csv("../../Dataset/CSVs/Datasets/SEANIMALMOVEBackgroundWOPAMDay.csv", index=False)

# print(len(df_processed_wmm))

# %% [markdown]
# ### SEANIMALMOVE - Background (Anthropogenic, ferries, motor boat... from NO WOPAM Day (4-5-6 June) )

# %%
# Background ferries
# Read all audio files in the input folder and its subfolders and set them as class Background
# Main Folder with all classes and files
audio_files = []

main_folder = '../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/'

classes = os.listdir(main_folder)

# Loop through all the subfolders and files
for subfolder in classes:
    # Get the list of all files in the subfolder
    files = os.listdir(main_folder + subfolder)
    # Loop through all the files
    for f in files:
        # Get the full path of the file
        audio_files.append(main_folder + subfolder + '/' + f)

df_bg_seanimalmove_nowopam = pd.DataFrame(audio_files, columns=['File'])

# Add class
# df_bg_seanimalmove_wopam['Class'] = "Background"
# total_duration = 0
# Number of files per class and duration of each file

df_bg_seanimalmove_nowopam['Class'] = df_bg_seanimalmove_nowopam['File'].apply(lambda x: x.split('/')[-2])

for f in audio_files:
    
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_bg_seanimalmove_nowopam.loc[df_bg_seanimalmove_nowopam['File'] == f, 'Duration'] = duration
    # total_duration += duration

# %%
df_bg_seanimalmove_nowopam
# Out:
#                                                  File            Class  \
# 0   ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/M...       Motor_boat
# 1   ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/M...       Motor_boat
# 2   ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/M...       Motor_boat
# 3   ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/M...       Motor_boat
# 4   ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/M...       Motor_boat
# ..                                                ...              ...
# 92  ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/F...  Ferry_FastFerry
# 93  ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/F...  Ferry_FastFerry
# 94  ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/F...  Ferry_FastFerry
# 95  ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/F...  Ferry_FastFerry
# 96  ../../Dataset/Audios/SEANIMALMOVE/NOWOPAMDay/F...  Ferry_FastFerry
#
#     Duration
# 0        3.0
# 1        3.0
# 2        3.0
# 3        3.0
# 4        3.0
# ..       ...
# 92       3.0
# 93       3.0
# 94       3.0
# 95       3.0
# 96       3.0
#
# [97 rows x 3 columns]

# %%
# Split background
df_train_bg_seanimalmove_nowopam, df_val_bg_seanimalmove_nowopam, df_test_bg_seanimalmove_nowopam, _, _, _ = split_dataset(df_bg_seanimalmove_nowopam, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
df_train_bg_seanimalmove_nowopam["Subset"] = "train"
df_val_bg_seanimalmove_nowopam["Subset"] = "val"
df_test_bg_seanimalmove_nowopam["Subset"] = "test"

df_bg_seanimalmove_nowopam = pd.concat([df_train_bg_seanimalmove_nowopam, df_val_bg_seanimalmove_nowopam, df_test_bg_seanimalmove_nowopam])

# %%
# For each file in the dataset, process the audio segmenting it in 3 seconds windows, if any of the segments is shorter, save it if it is at least 0.2 second long
# Create a new dataframe with the processed files maintaining original FilePath, Class, Subset, and Duration and include SegmentPath
processed_files = []

# target_sr = 48000
duration = 3

min_duration = 3

for _, row in df_bg_seanimalmove_nowopam.iterrows():

    # Load audio
    file_path = row["File"]

    # print("Audio Sample Rate: ", audio_sr)
    # print("Audio Duration: ", len(audio) / audio_sr)
    # print("Audio Samples: ", len(audio))
    

    processed_files.append({
        "FilePath": file_path,
        "SegmentPath": file_path,
        "Class": row["Class"],
        "Duration": 3,
        "Origin": "SEANIMALMOVE Background NOWOPAM Day",
        "Subset": row["Subset"]
    })
    

df_bg_seanimalmove_nowopam = pd.DataFrame(processed_files)

# save as CSV in CSV folder
df_bg_seanimalmove_nowopam.to_csv("../../Dataset/CSVs/Datasets/SEANIMALMOVEBackgroundNOWOPAMDay.csv", index=False)

# print(len(df_processed_wmm))

# %%
# Add class Background to classes
CLASSES = np.append(CLASSES, 'Background')
# sORT alphabetically
CLASSES.sort()

# include CLASSES_MAPPING, REVERSE_CLASSES_MAPPING the background class as the first class
CLASSES_MAPPING = {CLASSES[i]: i for i in range(len(CLASSES))}
REVERSE_CLASSES_MAPPING = {v: k for k, v in CLASSES_MAPPING.items()}
CLASSES, CLASSES_MAPPING, REVERSE_CLASSES_MAPPING
# Out:
# (array(['AtlanticSpottedDolphin', 'Background', 'BeardedSeal',
#         'Beluga_WhiteWhale', 'BottlenoseDolphin',
#         'Boutu_AmazonRiverDolphin', 'BowheadWhale', 'ClymeneDolphin',
#         'CommonDolphin', "Dall'sPorpoise", 'DuskyDolphin',
#         'FalseKillerWhale', 'Fin_FinbackWhale', "Fraser'sDolphin",
#         "Grampus_Risso'sDolphin", 'GrayWhale', 'HarborPorpoise',
#         'HarpSeal', "Heaviside'sDolphin", 'HumpbackWhale', 'KillerWhale',
#         'LeopardSeal', 'LongBeaked(Pacific)CommonDolphin',
#         'Long_FinnedPilotWhale', 'MelonHeadedWhale', 'MinkeWhale',
#         'Narwhal', 'NorthernRightWhale', 'PantropicalSpottedDolphin',
#         'RibbonSeal', 'RingedSeal', 'RossSeal', 'Rough_ToothedDolphin',
#         'Short_Finned(Pacific)PilotWhale', 'SouthernRightWhale',
#         'SpermWhale', 'SpinnerDolphin', 'SpottedSeal', 'StripedDolphin',
#         'TucuxiDolphin', 'Walrus', 'WeddellSeal', 'WestIndianManatee',
#         'White_beakedDolphin', 'White_sidedDolphin'], dtype=object),
#  {'AtlanticSpottedDolphin': 0,
#   'Background': 1,
#   'BeardedSeal': 2,
#   'Beluga_WhiteWhale': 3,
#   'BottlenoseDolphin': 4,
#   'Boutu_AmazonRiverDolphin': 5,
#   'BowheadWhale': 6,
#   'ClymeneDolphin': 7,
#   'CommonDolphin': 8,
#   "Dall'sPorpoise": 9,
#   'DuskyDolphin': 10,
#   'FalseKillerWhale': 11,
#   'Fin_FinbackWhale': 12,
#   "Fraser'sDolphin": 13,
#   "Grampus_Risso'sDolphin": 14,
#   'GrayWhale': 15,
#   'HarborPorpoise': 16,
#   'HarpSeal': 17,
#   "Heaviside'sDolphin": 18,
#   'HumpbackWhale': 19,
#   'KillerWhale': 20,
#   'LeopardSeal': 21,
#   'LongBeaked(Pacific)CommonDolphin': 22,
#   'Long_FinnedPilotWhale': 23,
#   'MelonHeadedWhale': 24,
#   'MinkeWhale': 25,
#   'Narwhal': 26,
#   'NorthernRightWhale': 27,
#   'PantropicalSpottedDolphin': 28,
#   'RibbonSeal': 29,
#   'RingedSeal': 30,
#   'RossSeal': 31,
#   'Rough_ToothedDolphin': 32,
#   'Short_Finned(Pacific)PilotWhale': 33,
#   'SouthernRightWhale': 34,
#   'SpermWhale': 35,
#   'SpinnerDolphin': 36,
#   'SpottedSeal': 37,
#   'StripedDolphin': 38,
#   'TucuxiDolphin': 39,
#   'Walrus': 40,
#   'WeddellSeal': 41,
#   'WestIndianManatee': 42,
#   'White_beakedDolphin': 43,
#   'White_sidedDolphin': 44},
#  {0: 'AtlanticSpottedDolphin',
#   1: 'Background',
#   2: 'BeardedSeal',
#   3: 'Beluga_WhiteWhale',
#   4: 'BottlenoseDolphin',
#   5: 'Boutu_AmazonRiverDolphin',
#   6: 'BowheadWhale',
#   7: 'ClymeneDolphin',
#   8: 'CommonDolphin',
#   9: "Dall'sPorpoise",
#   10: 'DuskyDolphin',
#   11: 'FalseKillerWhale',
#   12: 'Fin_FinbackWhale',
#   13: "Fraser'sDolphin",
#   14: "Grampus_Risso'sDolphin",
#   15: 'GrayWhale',
#   16: 'HarborPorpoise',
#   17: 'HarpSeal',
#   18: "Heaviside'sDolphin",
#   19: 'HumpbackWhale',
#   20: 'KillerWhale',
#   21: 'LeopardSeal',
#   22: 'LongBeaked(Pacific)CommonDolphin',
#   23: 'Long_FinnedPilotWhale',
#   24: 'MelonHeadedWhale',
#   25: 'MinkeWhale',
#   26: 'Narwhal',
#   27: 'NorthernRightWhale',
#   28: 'PantropicalSpottedDolphin',
#   29: 'RibbonSeal',
#   30: 'RingedSeal',
#   31: 'RossSeal',
#   32: 'Rough_ToothedDolphin',
#   33: 'Short_Finned(Pacific)PilotWhale',
#   34: 'SouthernRightWhale',
#   35: 'SpermWhale',
#   36: 'SpinnerDolphin',
#   37: 'SpottedSeal',
#   38: 'StripedDolphin',
#   39: 'TucuxiDolphin',
#   40: 'Walrus',
#   41: 'WeddellSeal',
#   42: 'WestIndianManatee',
#   43: 'White_beakedDolphin',
#   44: 'White_sidedDolphin'})

# %% [markdown]
# ### CIRCE - Pilot Whale

# %%
# Main Folder with all classes and files
main_folder = '../../Dataset/Audios/CIRCE/'

# Folder contains subfolders = classes and in them, the audio sample
classes = os.listdir(main_folder)

# remove folder Segmented
# classes.remove('Segmented')

# delete README.MD
# classes.remove('README.MD')

# Create an empty list to store the audio file paths
audio_files = []

# Loop through all the subfolders and files
for subfolder in classes:
    # Get the list of all files in the subfolder
    files = os.listdir(main_folder + subfolder)
    # Loop through all the files
    for f in files:
        # Get the full path of the file
        audio_files.append(main_folder + subfolder + '/' + f)

df_circe_mm = pd.DataFrame(audio_files, columns=['File'])

# Add class
df_circe_mm['Class'] = df_circe_mm['File'].apply(lambda x: x.split('/')[-2])

# Number of files per class and duration of each file
for f in audio_files:
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_circe_mm.loc[df_circe_mm['File'] == f, 'Duration'] = duration

df_circe_mm
# Out:
#                                                   File                  Class  \
# 0    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 1    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 2    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 3    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 4    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# ..                                                 ...                    ...
# 146  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 147  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 148  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 149  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 150  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
#
#      Duration
# 0    1.204263
# 1    0.653107
# 2    0.232109
# 3    0.483039
# 4    2.107664
# ..        ...
# 146  0.232109
# 147  1.003311
# 148  1.236780
# 149  0.288753
# 150  0.990975
#
# [151 rows x 3 columns]

# %%
# split neus
df_train_circe, df_val_circe, df_test_circe_mm, _, _, _ = split_dataset(df_circe_mm, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
df_train_circe["Subset"] = "train"
df_val_circe["Subset"] = "val"
df_test_circe_mm["Subset"] = "test"

df_circe_mm = pd.concat([df_train_circe, df_val_circe, df_test_circe_mm])

# %%
df_circe_mm
# Out:
#                                                  File                  Class  \
# 0   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 1   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 2   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 3   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 4   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# ..                                                ...                    ...
# 18  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 19  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 20  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 21  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 22  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
#
#     Duration Subset
# 0   1.918776  train
# 1   1.638005  train
# 2   0.940227  train
# 3   1.204263  train
# 4   1.242177  train
# ..       ...    ...
# 18  0.633651   test
# 19  0.364218   test
# 20  0.653107   test
# 21  0.351247   test
# 22  1.613152   test
#
# [151 rows x 4 columns]

# %%
# File is FilePath
df_circe_mm.rename(columns={"File": "FilePath"}, inplace=True)
df_circe_mm["SegmentPath"] = df_circe_mm["FilePath"]
df_circe_mm["Origin"] = "CIRCE Marine Mammals"

# resort columns: filepath, segmentpath, class, duration, origin, subset
df_circe_mm = df_circe_mm[['FilePath', 'SegmentPath', 'Class', 'Duration', 'Origin', 'Subset']]
#save as CSV in CSV folder
df_circe_mm.to_csv("../../Dataset/CSVs/Datasets/CIRCEMarineMammalsSegmented.csv", index=False)

# %% [markdown]
# ### CIRCE - FastFerry

# %%
# Background ferries
# Read all audio files in the input folder and its subfolders and set them as class Background
# Main Folder with all classes and files
audio_files = []

main_folder = '../../Dataset/Audios/CIRCE/'

classes = os.listdir(main_folder)

# Loop through all the subfolders and files
for subfolder in classes:
    # Get the list of all files in the subfolder
    files = os.listdir(main_folder + subfolder)
    # Loop through all the files
    for f in files:
        # Get the full path of the file
        audio_files.append(main_folder + subfolder + '/' + f)

df_bg_circe = pd.DataFrame(audio_files, columns=['File'])

# Add class
# df_bg_seanimalmove_wopam['Class'] = "Background"
# total_duration = 0
# Number of files per class and duration of each file

df_bg_circe['Class'] = df_bg_circe['File'].apply(lambda x: x.split('/')[-2])

for f in audio_files:
    
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_bg_circe.loc[df_bg_circe['File'] == f, 'Duration'] = duration
    # total_duration += duration

# %%
df_bg_circe = df_bg_circe[df_bg_circe['Class'] != 'Long_FinnedPilotWhale']
df_bg_circe.reset_index(drop=True, inplace=True)
df_bg_circe
# Out:
#                                                 File            Class  \
# 0  ../../Dataset/Audios/CIRCE/Motor_boat/Ww_Turma...       Motor_boat
# 1  ../../Dataset/Audios/CIRCE/Motor_boat/Ww_Firm0...       Motor_boat
# 2  ../../Dataset/Audios/CIRCE/Motor_boat/Ww_Turma...       Motor_boat
# 3  ../../Dataset/Audios/CIRCE/Motor_boat/Ww_Firm0...       Motor_boat
# 4  ../../Dataset/Audios/CIRCE/Motor_boat/Ww_Firm0...       Motor_boat
# 5  ../../Dataset/Audios/CIRCE/Ferry_FastFerry/Fas...  Ferry_FastFerry
# 6  ../../Dataset/Audios/CIRCE/Ferry_FastFerry/Fas...  Ferry_FastFerry
# 7  ../../Dataset/Audios/CIRCE/Ferry_FastFerry/Fas...  Ferry_FastFerry
# 8  ../../Dataset/Audios/CIRCE/Ferry_FastFerry/Fas...  Ferry_FastFerry
#
#      Duration
# 0  107.174649
# 1  139.199909
# 2  107.174649
# 3  158.576327
# 4   91.691746
# 5  123.530794
# 6  135.429025
# 7  118.463175
# 8   89.336372

# %%
# Split background
df_train_bg_circe, df_val_bg_circe, df_test_bg_circe, _, _, _ = split_dataset(df_bg_circe, train_size=0.5, val_size=0.25, test_size=0.25)

# %%
df_train_bg_circe["Subset"] = "train"
df_val_bg_circe["Subset"] = "val"
df_test_bg_circe["Subset"] = "test"

df_bg_circe = pd.concat([df_train_bg_circe, df_val_bg_circe, df_test_bg_circe])

# %%
# For each file in the dataset, process the audio segmenting it in 3 seconds windows, if any of the segments is shorter, save it if it is at least 0.2 second long
# Create a new dataframe with the processed files maintaining original FilePath, Class, Subset, and Duration and include SegmentPath
processed_files = []

# target_sr = 48000
duration = 3

min_duration = 3

for _, row in df_bg_circe.iterrows():

    # Load audio
    file_path = row["File"]
    audio, audio_sr = librosa.load(file_path, sr=None)

    # print("Audio Sample Rate: ", audio_sr)
    # print("Audio Duration: ", len(audio) / audio_sr)
    # print("Audio Samples: ", len(audio))
    
    # Calculate the maximum length in samples and min length in samples
    max_length = audio_sr * duration  # e.g., 48000 * 3
    min_length = audio_sr * min_duration  # e.g., 48000 * 1
    
    # If the signal is shorter than the desired length, save
    if min_length <= len(audio) <= max_length:
        # start_sample = int(Fs * (row['StartSecond'] + 1))  # Convertir a muestras
        # end_sample = int(Fs * (row['EndSecond'] + 1))  # Convertir a muestras
        audio_class = row['Class']

        # Crear la carpeta para la clase
        class_folder = "../../Dataset/Audios/CIRCE/Segmented/" + audio_class
        os.makedirs(class_folder, exist_ok=True)

        end_second = len(audio) / audio_sr
        end_second = round(end_second, 2)

        # Guardar el segmento
        segment_path = row["File"].split("Neus")[0] + "CIRCE/Segmented/" + audio_class + "/"	
        base_filename = os.path.basename(row["File"])
        segment_path += base_filename.replace(".wav", f"_0_{end_second}.wav")
        sf.write(segment_path, audio, audio_sr)

        processed_files.append({
            "FilePath": row["File"],
            "SegmentPath": segment_path,
            "Class": row["Class"],
            "Duration": len(audio) / audio_sr,
            "Origin": "CIRCE Background Fast Ferries",
            "Subset": row["Subset"]
        })
    
    # If the signal is longer than the desired length, split into 3-second windows
    elif len(audio) > max_length:

        for start in range(0, len(audio), max_length):
            end = start + max_length
            segment = audio[start:end]
            
            if min_length <= len(segment) <= max_length:
            #     padding = max_length - len(segment)
            #     pad_left = padding // 2
            #     pad_right = padding - pad_left
            #     segment = np.pad(segment, (pad_left, pad_right), mode='constant')
            
                # Save segment in corresponding folder
                audio_class = row['Class']
                class_folder = "../../Dataset/Audios/CIRCE/Segmented/" + audio_class
                os.makedirs(class_folder, exist_ok=True)

                start_second = start / audio_sr
                end_second = end / audio_sr

                # round to 2 decimal places
                end_second = round(end_second, 2)

                segment_path = row["File"].split("CIRCE")[0] + "CIRCE/Segmented/" + audio_class + "/"
                base_filename = os.path.basename(row["File"])
                segment_path += base_filename.replace(".wav", f"_{start_second}_{end_second}.wav")
                # print(segment_path)
                sf.write(segment_path, segment, audio_sr)

                processed_files.append({
                    "FilePath": row["File"],
                    "SegmentPath": segment_path,
                    "Class": row["Class"],
                    "Duration": len(segment) / audio_sr,
                    "Origin": "CIRCE Background Fast Ferries",
                    "Subset": row["Subset"]
                })

df_bg_circe = pd.DataFrame(processed_files)

# save as CSV in CSV folder
df_bg_circe.to_csv("../../Dataset/CSVs/Datasets/CIRCEBackgroundFastFerries.csv", index=False)

# print(len(df_processed_wmm))

# %%
# Add class Background to classes
CLASSES = np.append(CLASSES, 'Background')
# sORT alphabetically
CLASSES.sort()

# include CLASSES_MAPPING, REVERSE_CLASSES_MAPPING the background class as the first class
CLASSES_MAPPING = {CLASSES[i]: i for i in range(len(CLASSES))}
REVERSE_CLASSES_MAPPING = {v: k for k, v in CLASSES_MAPPING.items()}
CLASSES, CLASSES_MAPPING, REVERSE_CLASSES_MAPPING
# Out:
# (array(['AtlanticSpottedDolphin', 'Background', 'BeardedSeal',
#         'Beluga_WhiteWhale', 'BottlenoseDolphin',
#         'Boutu_AmazonRiverDolphin', 'BowheadWhale', 'ClymeneDolphin',
#         'CommonDolphin', "Dall'sPorpoise", 'DuskyDolphin',
#         'FalseKillerWhale', 'Fin_FinbackWhale', "Fraser'sDolphin",
#         "Grampus_Risso'sDolphin", 'GrayWhale', 'HarborPorpoise',
#         'HarpSeal', "Heaviside'sDolphin", 'HumpbackWhale', 'KillerWhale',
#         'LeopardSeal', 'LongBeaked(Pacific)CommonDolphin',
#         'Long_FinnedPilotWhale', 'MelonHeadedWhale', 'MinkeWhale',
#         'Narwhal', 'NorthernRightWhale', 'PantropicalSpottedDolphin',
#         'RibbonSeal', 'RingedSeal', 'RossSeal', 'Rough_ToothedDolphin',
#         'Short_Finned(Pacific)PilotWhale', 'SouthernRightWhale',
#         'SpermWhale', 'SpinnerDolphin', 'SpottedSeal', 'StripedDolphin',
#         'TucuxiDolphin', 'Walrus', 'WeddellSeal', 'WestIndianManatee',
#         'White_beakedDolphin', 'White_sidedDolphin'], dtype=object),
#  {'AtlanticSpottedDolphin': 0,
#   'Background': 1,
#   'BeardedSeal': 2,
#   'Beluga_WhiteWhale': 3,
#   'BottlenoseDolphin': 4,
#   'Boutu_AmazonRiverDolphin': 5,
#   'BowheadWhale': 6,
#   'ClymeneDolphin': 7,
#   'CommonDolphin': 8,
#   "Dall'sPorpoise": 9,
#   'DuskyDolphin': 10,
#   'FalseKillerWhale': 11,
#   'Fin_FinbackWhale': 12,
#   "Fraser'sDolphin": 13,
#   "Grampus_Risso'sDolphin": 14,
#   'GrayWhale': 15,
#   'HarborPorpoise': 16,
#   'HarpSeal': 17,
#   "Heaviside'sDolphin": 18,
#   'HumpbackWhale': 19,
#   'KillerWhale': 20,
#   'LeopardSeal': 21,
#   'LongBeaked(Pacific)CommonDolphin': 22,
#   'Long_FinnedPilotWhale': 23,
#   'MelonHeadedWhale': 24,
#   'MinkeWhale': 25,
#   'Narwhal': 26,
#   'NorthernRightWhale': 27,
#   'PantropicalSpottedDolphin': 28,
#   'RibbonSeal': 29,
#   'RingedSeal': 30,
#   'RossSeal': 31,
#   'Rough_ToothedDolphin': 32,
#   'Short_Finned(Pacific)PilotWhale': 33,
#   'SouthernRightWhale': 34,
#   'SpermWhale': 35,
#   'SpinnerDolphin': 36,
#   'SpottedSeal': 37,
#   'StripedDolphin': 38,
#   'TucuxiDolphin': 39,
#   'Walrus': 40,
#   'WeddellSeal': 41,
#   'WestIndianManatee': 42,
#   'White_beakedDolphin': 43,
#   'White_sidedDolphin': 44},
#  {0: 'AtlanticSpottedDolphin',
#   1: 'Background',
#   2: 'BeardedSeal',
#   3: 'Beluga_WhiteWhale',
#   4: 'BottlenoseDolphin',
#   5: 'Boutu_AmazonRiverDolphin',
#   6: 'BowheadWhale',
#   7: 'ClymeneDolphin',
#   8: 'CommonDolphin',
#   9: "Dall'sPorpoise",
#   10: 'DuskyDolphin',
#   11: 'FalseKillerWhale',
#   12: 'Fin_FinbackWhale',
#   13: "Fraser'sDolphin",
#   14: "Grampus_Risso'sDolphin",
#   15: 'GrayWhale',
#   16: 'HarborPorpoise',
#   17: 'HarpSeal',
#   18: "Heaviside'sDolphin",
#   19: 'HumpbackWhale',
#   20: 'KillerWhale',
#   21: 'LeopardSeal',
#   22: 'LongBeaked(Pacific)CommonDolphin',
#   23: 'Long_FinnedPilotWhale',
#   24: 'MelonHeadedWhale',
#   25: 'MinkeWhale',
#   26: 'Narwhal',
#   27: 'NorthernRightWhale',
#   28: 'PantropicalSpottedDolphin',
#   29: 'RibbonSeal',
#   30: 'RingedSeal',
#   31: 'RossSeal',
#   32: 'Rough_ToothedDolphin',
#   33: 'Short_Finned(Pacific)PilotWhale',
#   34: 'SouthernRightWhale',
#   35: 'SpermWhale',
#   36: 'SpinnerDolphin',
#   37: 'SpottedSeal',
#   38: 'StripedDolphin',
#   39: 'TucuxiDolphin',
#   40: 'Walrus',
#   41: 'WeddellSeal',
#   42: 'WestIndianManatee',
#   43: 'White_beakedDolphin',
#   44: 'White_sidedDolphin'})

# %% [markdown]
# ### CIRCE - Pilot Whale

# %%
# Main Folder with all classes and files
main_folder = '../../Dataset/Audios/CIRCE/'

# Folder contains subfolders = classes and in them, the audio sample
classes = os.listdir(main_folder)

# remove folder Segmented
# classes.remove('Segmented')

# delete README.MD
# classes.remove('README.MD')

# Create an empty list to store the audio file paths
audio_files = []

# Loop through all the subfolders and files
for subfolder in classes:
    # Get the list of all files in the subfolder
    files = os.listdir(main_folder + subfolder)
    # Loop through all the files
    for f in files:
        # Get the full path of the file
        audio_files.append(main_folder + subfolder + '/' + f)

df_circe_mm = pd.DataFrame(audio_files, columns=['File'])

# Add class
df_circe_mm['Class'] = df_circe_mm['File'].apply(lambda x: x.split('/')[-2])

# Number of files per class and duration of each file
for f in audio_files:
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_circe_mm.loc[df_circe_mm['File'] == f, 'Duration'] = duration

df_circe_mm
# Out:
#                                                   File                  Class  \
# 0    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 1    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 2    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 3    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 4    ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# ..                                                 ...                    ...
# 146  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 147  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 148  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 149  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 150  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
#
#      Duration
# 0    1.204263
# 1    0.653107
# 2    0.232109
# 3    0.483039
# 4    2.107664
# ..        ...
# 146  0.232109
# 147  1.003311
# 148  1.236780
# 149  0.288753
# 150  0.990975
#
# [151 rows x 3 columns]

# %%
# split neus
df_train_circe, df_val_circe, df_test_circe_mm, _, _, _ = split_dataset(df_circe_mm, train_size=0.7, val_size=0.15, test_size=0.15)

# %%
df_train_circe["Subset"] = "train"
df_val_circe["Subset"] = "val"
df_test_circe_mm["Subset"] = "test"

df_circe_mm = pd.concat([df_train_circe, df_val_circe, df_test_circe_mm])

# %%
df_circe_mm
# Out:
#                                                  File                  Class  \
# 0   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 1   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 2   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 3   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 4   ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# ..                                                ...                    ...
# 18  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 19  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 20  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 21  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
# 22  ../../Dataset/Audios/CIRCE/Long_FinnedPilotWha...  Long_FinnedPilotWhale
#
#     Duration Subset
# 0   1.918776  train
# 1   1.638005  train
# 2   0.940227  train
# 3   1.204263  train
# 4   1.242177  train
# ..       ...    ...
# 18  0.633651   test
# 19  0.364218   test
# 20  0.653107   test
# 21  0.351247   test
# 22  1.613152   test
#
# [151 rows x 4 columns]

# %%
# File is FilePath
df_circe_mm.rename(columns={"File": "FilePath"}, inplace=True)
df_circe_mm["SegmentPath"] = df_circe_mm["FilePath"]
df_circe_mm["Origin"] = "CIRCE Marine Mammals"

# resort columns: filepath, segmentpath, class, duration, origin, subset
df_circe_mm = df_circe_mm[['FilePath', 'SegmentPath', 'Class', 'Duration', 'Origin', 'Subset']]
#save as CSV in CSV folder
df_circe_mm.to_csv("../../Dataset/CSVs/Datasets/CIRCEMarineMammalsSegmented.csv", index=False)

# %% [markdown]
# ## Final Dataset

# %%
# Load all CSVs
df_wmm = pd.read_csv('../../Dataset/CSVs/Datasets/WatkinsMarineMammalsSegmented.csv')
df_neus_mm = pd.read_csv('../../Dataset/CSVs/Datasets/NeusMarineMammalsSegmented.csv')
df_sam_background = pd.read_csv('../../Dataset/CSVs/Datasets/SEANIMALMOVEBackgroundSegmented.csv')
df_bg_ff_neus = pd.read_csv('../../Dataset/CSVs/Datasets/NeusBackgroundFastFerries.csv')
df_bg_seanimalmove_wopam = pd.read_csv('../../Dataset/CSVs/Datasets/SEANIMALMOVEBackgroundWOPAMDay.csv')
df_bg_seanimalmove_nowopam = pd.read_csv('../../Dataset/CSVs/Datasets/SEANIMALMOVEBackgroundNOWOPAMDay.csv')
df_circe_mm = pd.read_csv('../../Dataset/CSVs/Datasets/CIRCEMarineMammalsSegmented.csv')
df_circe_bg = pd.read_csv('../../Dataset/CSVs/Datasets/CIRCEBackgroundFastFerries.csv')

# %%
# From watkins take only: 
df_wmm = df_wmm[df_wmm['Class'].isin(['BottlenoseDolphin', 'CommonDolphin', "Grampus_Risso'sDolphin", 'HarborPorpoise', 'KillerWhale', 'Long_FinnedPilotWhale', 'StripedDolphin'])]
# reset index
df_wmm.reset_index(drop=True, inplace=True)

# %%
df = pd.concat([df_wmm, df_neus_mm, df_sam_background, df_bg_ff_neus, df_bg_seanimalmove_wopam, df_bg_seanimalmove_nowopam, df_circe_mm, df_circe_bg])

# %%
# save as dataset.csv
df.to_csv("../../Dataset/CSVs/Datasets/Dataset.csv", index=False)

# %%
# read csv
df = pd.read_csv('../../Dataset/CSVs/Datasets/Dataset.csv')

# %%
# unique origin of rows with Class Background
df[df['Class'] == 'Background']['Origin'].unique()
# Out:
# array(['SEANIMALMOVE'], dtype=object)

# %%
# Make FastFerry, MotorBoat, Cargo and HumanDiver Background class
df.loc[df['Class'].isin(['Ferry_FastFerry', 'Motor_boat', 'Cargo', 'Human_diver']), 'Class'] = 'Background'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot count per class, each subset is a bar for each class (train, val and test)
class_counts = df['Class'].value_counts().sort_values(ascending=False)

plt.figure(figsize=(14, 8))
sns.countplot(data=df, x='Class', order=class_counts.index)
# plt.title('Number of Files per Class in Each Set')
plt.xticks(rotation=45, ha='right', fontsize=10)  # Adjust fontsize and alignment
plt.legend(title='Set')
plt.ylabel('Number of Files')
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()

# Show Sum of Duration per class
df_duration = df.groupby('Class')['Duration'].sum().sort_values(ascending=False)

# Plot sum of duration per class
plt.figure(figsize=(14, 8))
sns.barplot(x=df_duration.index, y=df_duration.values)
# plt.title('Sum of Duration per Class')
plt.xticks(rotation=45, ha='right', fontsize=10)  # Adjust fontsize and alignment
plt.ylabel('Duration (s)')
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create a plot to see the proportion of each Origin in each class and subset
plt.figure(figsize=(14, 8))
sns.countplot(data=df, x='Class', hue='Origin', order=class_counts.index)
plt.title('Number of Files per Class in Each Set')
plt.xticks(rotation=45, ha='right', fontsize=10)  # Adjust fontsize and alignment
plt.legend(title='Origin')
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_train, df_val, df_test are already defined and have a 'Duration' column

# Add 'Set' column
df_train['Set'] = 'Train'
df_val['Set'] = 'Validation'
df_test['Set'] = 'Test'

# Concatenate all dataframes
df = pd.concat([df_train, df_val, df_test])

# Aggregate total duration per class and subset
duration_df = df.groupby(['Class', 'Set'])['Duration'].sum().reset_index()

# Ensure the order of the bars is Train, Validation, and Test
duration_df['Set'] = pd.Categorical(duration_df['Set'], categories=['Train', 'Validation', 'Test'], ordered=True)

# Plot the total duration per class and subset
plt.figure(figsize=(14, 8))
sns.barplot(data=duration_df, x='Class', y='Duration', hue='Set', order=class_counts.index)
plt.title('Total Duration per Class in Each Set')
plt.xticks(rotation=90, ha='right', fontsize=10)  # Adjust fontsize and alignment
plt.ylabel('Total Duration (seconds)')
plt.legend(title='Set')
plt.tight_layout()  # Adjust layout to make room for labels
plt.show()

# %%
# reset index in all sets
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
CLASSES_MAPPING
# Out:
# {'Background': 0,
#  'BottlenoseDolphin': 1,
#  'CommonDolphin': 2,
#  'Fin_FinbackWhale': 3,
#  "Grampus_Risso'sDolphin": 4,
#  'HarborPorpoise': 5,
#  'HumpbackWhale': 6,
#  'KillerWhale': 7,
#  'Long_FinnedPilotWhale': 8,
#  'MinkeWhale': 9,
#  'SpermWhale': 10,
#  'StripedDolphin': 11}

# %% [markdown]
# ## Elena Papale - Test

# %%
# Main Folder with all classes and files
main_folder = '../../Dataset/Audios/ElenaPapale/'

# Folder contains subfolders = classes and in them, the audio sample
classes = os.listdir(main_folder)

# remove folder Segmented
# classes.remove('Segmented')

# delete README.MD
# classes.remove('README.MD')

# Create an empty list to store the audio file paths
audio_files = []

# Loop through all the subfolders and files
for subfolder in classes:
    # Get the list of all files in the subfolder
    files = os.listdir(main_folder + subfolder)
    # Loop through all the files
    for f in files:
        # Get the full path of the file
        audio_files.append(main_folder + subfolder + '/' + f)

df_elena_fb = pd.DataFrame(audio_files, columns=['File'])

# Add class
df_elena_fb['Class'] = df_elena_fb['File'].apply(lambda x: x.split('/')[-2])

# Number of files per class and duration of each file
for f in audio_files:
    # Load the audio file
    x, sr = librosa.load(f)
    # Duration of the audio file
    duration = librosa.get_duration(y=x, sr=sr)
    # Add the duration to the duration list
    df_elena_fb.loc[df_elena_fb['File'] == f, 'Duration'] = duration

# %%
df_elena_fb
# Out:
#                                                 File             Class  \
# 0  ../../Dataset/Audios/ElenaPapale/Fin_FinbackWh...  Fin_FinbackWhale
# 1  ../../Dataset/Audios/ElenaPapale/Fin_FinbackWh...  Fin_FinbackWhale
#
#       Duration
# 0  1798.006032
# 1  1798.006032

# %%
# For each file in the dataset, process the audio segmenting it in 3 seconds windows, if any of the segments is shorter, save it if it is at least 0.2 second long
# Create a new dataframe with the processed files maintaining original FilePath, Class, Subset, and Duration and include SegmentPath
processed_files = []
# target_sr = 48000
duration = 3
min_duration = 2

# Define the segments to keep for each file
segments_to_keep = {
    'us500HzMS16-ISCHIA_20160819_080004.wav': [
        (1*60+36, 1*60+55),  # 1:36 to 1:55
        (3*60+5, 4*60+40)  # 3:05 to 4:40
    ],
    'us500HzMS16-ISCHIA_20160819_083004.wav': [
        (6*60+3, 11*60+50),  # 6:03 to 11:50
        (24*60+40, 27*60+50)  # 24:40 to 27:50
    ]
}

# Define the subsets for each segment
subsets = {
    'us500HzMS16-ISCHIA_20160819_080004.wav': 'train',
    'us500HzMS16-ISCHIA_20160819_083004.wav': ['test', 'validation']
}

for _, row in df_elena_fb.iterrows():
    # Load audio
    file_path = row["File"]
    base_filename = os.path.basename(file_path)
    if base_filename not in segments_to_keep:
        continue

    audio, audio_sr = librosa.load(file_path, sr=None)
    max_length = audio_sr * duration
    min_length = audio_sr * min_duration

    for i, (start_sec, end_sec) in enumerate(segments_to_keep[base_filename]):
        start_sample = int(start_sec * audio_sr)
        end_sample = int(end_sec * audio_sr)
        segment = audio[start_sample:end_sample]

        audio_class = row['Class']
        class_folder = "../../Dataset/Audios/ElenaPapale/Segmented/" + audio_class
        os.makedirs(class_folder, exist_ok=True)

        for seg_start in range(0, len(segment), max_length):
            seg_end = seg_start + max_length
            seg = segment[seg_start:seg_end]

            if min_length <= len(seg) <= max_length:
                seg_start_second = start_second + (seg_start / audio_sr)
                seg_end_second = start_second + (seg_end / audio_sr)
                seg_end_second = round(seg_end_second, 2)

                seg_path = row["File"].split("ElenaPapale")[0] + "ElenaPapale/Segmented/" + audio_class + "/"
                seg_path += base_filename.replace(".wav", f"_{seg_start_second}_{seg_end_second}.wav")
                sf.write(seg_path, seg, audio_sr)

                subset = subsets[base_filename]
                if isinstance(subset, list):
                    subset = subset[i]

                processed_files.append({
                    "FilePath": row["File"],
                    "SegmentPath": seg_path,
                    "Class": row["Class"],
                    "Duration": len(seg) / audio_sr,
                    "Origin": "ElenaPapale Fin Finback Whale",
                    "Subset": subset
                })

df_processed_neus = pd.DataFrame(processed_files)

# save as CSV in CSV folder
df_processed_neus.to_csv("../../Dataset/CSVs/Datasets/ElenaPapaleFinfinbackWhaleSegmented.csv", index=False)
