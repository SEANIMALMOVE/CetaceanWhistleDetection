# %% [markdown]
# # Segment audios

# %%
import os

# Data Management
import pandas as pd

import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Audio
from pydub import AudioSegment

# %%
# !ls ../DeepLearning/Validation/CSVs/
# Out:
# 15feb25_CommonDolphin.csv  15feb25_Long_FinnedPilotWhale.csv
# 15feb25_Grampus_Risso.csv  15feb25_StripedDolphin.csv
# 15feb25_KillerWhale.csv    wopamday_predictions_validated.csv

# %%
import pandas as pd

# Load CSV predictions.csv
df = pd.read_csv('../DeepLearning/Validation/CSVs/wopamday_predictions_validated.csv')
df
# Out:
#                                                   Path  \
# 0    NOWOPAM DAY_Downsampled/channelA_2024-06-04_01...
# 1    NOWOPAM DAY_Downsampled/channelA_2024-06-04_03...
# 2    NOWOPAM DAY_Downsampled/channelA_2024-06-04_04...
# 3    NOWOPAM DAY_Downsampled/channelA_2024-06-04_04...
# 4    NOWOPAM DAY_Downsampled/channelA_2024-06-04_05...
# ..                                                 ...
# 233  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 234  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 235  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 236  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 237  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
#
#                                    Filename  StartSecond  EndSecond  \
# 0    channelA_2024-06-04_01-48-06_48kHz.wav           63         66
# 1    channelA_2024-06-04_03-59-12_48kHz.wav           39         42
# 2    channelA_2024-06-04_04-14-12_48kHz.wav           45         48
# 3    channelA_2024-06-04_04-31-03_48kHz.wav          129        132
# 4    channelA_2024-06-04_05-31-36_48kHz.wav           42         45
# ..                                      ...          ...        ...
# 233  channelA_2024-06-06_23-21-22_48kHz.wav            6          9
# 234  channelA_2024-06-06_23-21-22_48kHz.wav           90         93
# 235  channelA_2024-06-06_23-21-22_48kHz.wav          255        258
# 236  channelA_2024-06-06_23-31-22_48kHz.wav           69         72
# 237  channelA_2024-06-06_23-43-13_48kHz.wav          162        165
#
#     MainClassification  ConfidenceScore  \
# 0          KillerWhale         0.568359
# 1          KillerWhale         0.566447
# 2          KillerWhale         0.510340
# 3          KillerWhale         0.525480
# 4          KillerWhale         0.640998
# ..                 ...              ...
# 233        KillerWhale         0.563988
# 234        KillerWhale         0.348022
# 235        KillerWhale         0.490302
# 236        KillerWhale         0.670108
# 237        KillerWhale         0.379464
#
#                                       ConfidenceVector
# 0    [0.41651639342308044, 0.0005951551138423383, 0...
# 1    [0.28282231092453003, 0.003969627898186445, 0....
# 2    [0.316283255815506, 0.017617404460906982, 0.03...
# 3    [0.2816283106803894, 0.0487314835190773, 0.027...
# 4    [0.2124193012714386, 0.04027629271149635, 0.01...
# ..                                                 ...
# 233  [0.10524842143058777, 0.023314744234085083, 0....
# 234  [0.3025113046169281, 0.03195066377520561, 0.09...
# 235  [0.27642950415611267, 0.011335188522934914, 0....
# 236  [0.1172894835472107, 0.00324572273530066, 0.01...
# 237  [0.37060388922691345, 0.05410251021385193, 0.0...
#
# [238 rows x 7 columns]

# %%
# newcolumn Downsampled File = File.replace('.WAV', '_48kHz.WAV')
df['Downsampled File'] = df['File'].str.replace('.WAV', '_48kHz.WAV')
df
# Out:
#                                                   Path  \
# 0    NOWOPAM DAY_Downsampled/channelA_2024-06-04_01...
# 1    NOWOPAM DAY_Downsampled/channelA_2024-06-04_03...
# 2    NOWOPAM DAY_Downsampled/channelA_2024-06-04_04...
# 3    NOWOPAM DAY_Downsampled/channelA_2024-06-04_04...
# 4    NOWOPAM DAY_Downsampled/channelA_2024-06-04_05...
# ..                                                 ...
# 233  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 234  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 235  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 236  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
# 237  NOWOPAM DAY_Downsampled/channelA_2024-06-06_23...
#
#                                    Filename  StartSecond  EndSecond  \
# 0    channelA_2024-06-04_01-48-06_48kHz.wav           63         66
# 1    channelA_2024-06-04_03-59-12_48kHz.wav           39         42
# 2    channelA_2024-06-04_04-14-12_48kHz.wav           45         48
# 3    channelA_2024-06-04_04-31-03_48kHz.wav          129        132
# 4    channelA_2024-06-04_05-31-36_48kHz.wav           42         45
# ..                                      ...          ...        ...
# 233  channelA_2024-06-06_23-21-22_48kHz.wav            6          9
# 234  channelA_2024-06-06_23-21-22_48kHz.wav           90         93
# 235  channelA_2024-06-06_23-21-22_48kHz.wav          255        258
# 236  channelA_2024-06-06_23-31-22_48kHz.wav           69         72
# 237  channelA_2024-06-06_23-43-13_48kHz.wav          162        165
#
#     MainClassification  ConfidenceScore  \
# 0          KillerWhale         0.568359
# 1          KillerWhale         0.566447
# 2          KillerWhale         0.510340
# 3          KillerWhale         0.525480
# 4          KillerWhale         0.640998
# ..                 ...              ...
# 233        KillerWhale         0.563988
# 234        KillerWhale         0.348022
# 235        KillerWhale         0.490302
# 236        KillerWhale         0.670108
# 237        KillerWhale         0.379464
#
#                                       ConfidenceVector  \
# 0    [0.41651639342308044, 0.0005951551138423383, 0...
# 1    [0.28282231092453003, 0.003969627898186445, 0....
# 2    [0.316283255815506, 0.017617404460906982, 0.03...
# 3    [0.2816283106803894, 0.0487314835190773, 0.027...
# 4    [0.2124193012714386, 0.04027629271149635, 0.01...
# ..                                                 ...
# 233  [0.10524842143058777, 0.023314744234085083, 0....
# 234  [0.3025113046169281, 0.03195066377520561, 0.09...
# 235  [0.27642950415611267, 0.011335188522934914, 0....
# 236  [0.1172894835472107, 0.00324572273530066, 0.01...
# 237  [0.37060388922691345, 0.05410251021385193, 0.0...
#
#                            Downsampled File
# 0    channelA_2024-06-04_01-48-06_48kHz.wav
# 1    channelA_2024-06-04_03-59-12_48kHz.wav
# 2    channelA_2024-06-04_04-14-12_48kHz.wav
# 3    channelA_2024-06-04_04-31-03_48kHz.wav
# 4    channelA_2024-06-04_05-31-36_48kHz.wav
# ..                                      ...
# 233  channelA_2024-06-06_23-21-22_48kHz.wav
# 234  channelA_2024-06-06_23-21-22_48kHz.wav
# 235  channelA_2024-06-06_23-21-22_48kHz.wav
# 236  channelA_2024-06-06_23-31-22_48kHz.wav
# 237  channelA_2024-06-06_23-43-13_48kHz.wav
#
# [238 rows x 8 columns]

# %%
species = df["Annotation"].unique()
species
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/DataAnalysis/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Annotation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 species = df["Annotation"].unique()
#       2 species
#
# File ~/anaconda3/envs/DataAnalysis/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/DataAnalysis/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Annotation'

# %%
# HARD_DRIVE = "f"
# OS = "WSL"

# import subprocess
# from NO_SHARABLE import PASSWORD

# if OS == "WSL":
#     command = f'mount -t drvfs F: /mnt/{HARD_DRIVE}'

#     try:
#         # Ejecutar el comando como sudo
#         proc = subprocess.Popen(
#             ['sudo', '-S'] + command.split(),
#             stdin=subprocess.PIPE,
#             stdout=subprocess.PIPE,
#             stderr=subprocess.PIPE,
#             universal_newlines=True
#         )

#         # Enviar la contraseña seguido de un salto de línea
#         stdout, stderr = proc.communicate(PASSWORD + '\n')

#         print('STDOUT:', stdout)
#         print('STDERR:', stderr)

#         if proc.returncode == 0:
#             print("Hard drive mounted successfully")
#             HARD_DRIVE = HARD_DRIVE
#         else:
#             print("Failed to mount hard drive")

#     except Exception as e:
#         print(f"An error occurred: {e}")

# %%
import os

# %%
for specie in species:
    # Load the subset
    subset = df[df["Annotation"] == specie]
    subset = subset.reset_index(drop=True)
    print(specie, len(subset))
# Out:
# Whistle 7
# Human_diver_1_breath 49
# Motor_boat 46
# Ferry_Fast ferry 51
# Human_diver_2_wee 4

# %%
import os
from pydub import AudioSegment
import pandas as pd

# %%
# HARD_DRIVE = "e"
# OS = "WSL"

# import subprocess

# if OS == "WSL":
#     command = f'mount -t drvfs E: /mnt/{HARD_DRIVE}'

#     try:
#         # Ejecutar el comando como sudo
#         proc = subprocess.Popen(
#             ['sudo', '-S'] + command.split(),
#             stdin=subprocess.PIPE,
#             stdout=subprocess.PIPE,
#             stderr=subprocess.PIPE,
#             universal_newlines=True
#         )

#         # Enviar la contraseña seguido de un salto de línea
#         stdout, stderr = proc.communicate(PASSWORD + '\n')

#         print('STDOUT:', stdout)
#         print('STDERR:', stderr)

#         if proc.returncode == 0:
#             print("Hard drive mounted successfully")
#             HARD_DRIVE = HARD_DRIVE
#         else:
#             print("Failed to mount hard drive")

#     except Exception as e:
#         print(f"An error occurred: {e}")

# %%
# !ls ../../../../mnt/e
# Out:
# '$RECYCLE.BIN'			        Start_Here_Chromebook.pdf
#  22_WOPAM_DAY			        Start_Here_Win.exe
#  Autorun.inf			       'System Volume Information'
# 'Deep Learning Analysis'	       'TARIFA 3 SYLENCE PAMGUARD'
#  Definir_Fechahora_Deteccion.m	       'Tarifa 1 RESEA 260424 a 050524'
#  Desarrollo			       'Tarifa 2 RESEA 270524 a 040624'
# 'Downsampled AQUI TAMBIÉN'	       'Tarifa 2 SYLENCE - AQUI'
# 'NOWOPAM DAY_Downsampled'	       'Tarifa 3 RESEA Junio'
# 'PAMGUARD RESULTADOS'		        Visualizardor_Detecciones.m
#  SEANIMALMOVE_hydrophoneSYLENCE_rms.m  'WOPAM DAY_Downsampled'
# 'SPL_OTROSparametros_Tarifa_1&2.xlsx'   Warranty.pdf
#  Seagate			        from_channelA_to_SM301165_0.m
#  Segments_DL22			        q_SEANIMALMOVE_SYLENCE_hydrophone_rms.m

# %%
df = df[df["Annotation"] != "Whistle"]

# %%
df["Annotation"].unique()
# Out:
# array(['Human_diver_1_breath', 'Motor_boat', 'Ferry_Fast ferry',
#        'Human_diver_2_wee'], dtype=object)

# %%
# !ls /mnt/e
# Out:
# '$RECYCLE.BIN'			        Start_Here_Chromebook.pdf
#  22_WOPAM_DAY			        Start_Here_Win.exe
#  Autorun.inf			       'System Volume Information'
# 'Deep Learning Analysis'	       'TARIFA 3 SYLENCE PAMGUARD'
#  Definir_Fechahora_Deteccion.m	       'Tarifa 1 RESEA 260424 a 050524'
#  Desarrollo			       'Tarifa 2 RESEA 270524 a 040624'
# 'Downsampled AQUI TAMBIÉN'	       'Tarifa 2 SYLENCE - AQUI'
# 'NOWOPAM DAY_Downsampled'	       'Tarifa 3 RESEA Junio'
# 'PAMGUARD RESULTADOS'		        Visualizardor_Detecciones.m
#  SEANIMALMOVE_hydrophoneSYLENCE_rms.m  'WOPAM DAY_Downsampled'
# 'SPL_OTROSparametros_Tarifa_1&2.xlsx'   Warranty.pdf
#  Seagate			        from_channelA_to_SM301165_0.m
#  Segments_DL22			        q_SEANIMALMOVE_SYLENCE_hydrophone_rms.m

# %%
df
# Out:
#                                  File  \
# 1    channelA_2024-06-08_11-17-36.WAV
# 2    channelA_2024-06-08_11-17-36.WAV
# 3    channelA_2024-06-08_15-34-48.WAV
# 4    channelA_2024-06-08_15-34-48.WAV
# 5    channelA_2024-06-08_15-34-48.WAV
# ..                                ...
# 151  channelA_2024-06-09_15-10-39.WAV
# 152  channelA_2024-06-09_15-27-30.WAV
# 153  channelA_2024-06-09_15-27-30.WAV
# 154  channelA_2024-06-09_15-27-30.WAV
# 155  channelA_2024-06-07_13-04-47.WAV
#
#                                            SegmentFile  StartSecond  \
# 1    channelA_2024-06-08_11-17-36_48kHz_229_236_0.4...          231
# 2    channelA_2024-06-08_11-17-36_48kHz_247_254_0.3...          249
# 3    channelA_2024-06-08_15-34-48_48kHz_154_161_0.6...          156
# 4    channelA_2024-06-08_15-34-48_48kHz_157_164_0.3...          159
# 5    channelA_2024-06-08_15-34-48_48kHz_160_167_0.4...          162
# ..                                                 ...          ...
py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EndSecond"] = df["EndSecond"] - 2

# %%
5 + 50 *48000
# Out:
# 2400005

# %%
def cut_audio(prediction, output_folder, audios_folder="../Audios/"):
    file = prediction["Downsampled File"]

    start_time = int(prediction["StartSecond"] * 1000)  # Convert to ms
    end_time = int(prediction["EndSecond"] * 1000)

    start_time = int(start_time)
    end_time = int(end_time)

    scientific_name = prediction["Annotation"]

    # Get the output folder
    output_folder_specie = os.path.join(output_folder, scientific_name)
    os.makedirs(output_folder_specie, exist_ok=True)

    # Get the output file path
    base_filename = os.path.basename(file)
    output_file = os.path.join(
        output_folder_specie, f"{base_filename.replace('.WAV', '')}_{start_time // 1000}_{end_time // 1000}.WAV"
    )

    if not os.path.exists(output_file):
        # Get the audio file
        audio_file = os.path.join(audios_folder, file)

        if not os.path.exists(audio_file):
            print(f"Warning: {audio_file} not found!")
            return

        # Load the audio file
        audio = AudioSegment.from_wav(audio_file)

        # Cut the audio segment
        cut_audio = audio[start_time:end_time]

        print(f"Exporting {output_file}...")

        # Export the cut audio segment
        cut_audio.export(output_file, format="wav")
    else:
        print(f"File {output_file} already exists")


AudioFolder = "../Dataset/Audios/SEANIMALMOVE/WOPAMDay/"

for specie in species:
    # Load the subset
    subset = df[df["Annotation"] == specie]
    # reset index
    subset = subset.reset_index(drop=True)
    # For each subset saved in a csv, save in a different folder
    output_folder = f"{AudioFolder}/"
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    # Cut the audio for each row in the subset
    for index, row in subset.iterrows():
        cut_audio(row, output_folder, audios_folder = f"/mnt/e/WOPAM DAY_Downsampled/")
# Out:
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_231_234.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_249_252.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_156_159.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_159_162.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_162_165.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_168_171.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_171_174.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_174_177.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_177_180.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_123_126.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_138_141.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_144_147.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_216_219.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_225_228.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_267_270.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_270_273.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_276_279.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_180_183.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_111_114.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_114_117.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_117_120.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_15-27-30_48kHz_267_270.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_15-27-30_48kHz_276_279.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_180_183.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_207_210.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_183_186.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_129_132.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_15-27-30_48kHz_282_285.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_15-27-30_48kHz_285_288.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_189_192.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_195_198.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_198_201.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_204_207.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_210_213.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_213_216.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_234_237.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_11-17-36_48kHz_258_261.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_135_138.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_138_141.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_150_153.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-08_15-34-48_48kHz_153_156.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_108_111.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_120_123.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_126_129.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_132_135.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_09-20-25_48kHz_96_99.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_15-27-30_48kHz_255_258.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_15-27-30_48kHz_279_282.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Human_diver_1_breath/channelA_2024-06-09_15-27-30_48kHz_288_291.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09_15-10-39_48kHz_255_258.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09_15-10-39_48kHz_270_273.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_08-17-49_48kHz_138_141.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_05-37-48_48kHz_114_117.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_06-21-30_48kHz_231_234.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_06-48-21_48kHz_297_300.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_06-53-21_48kHz_51_54.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_06-53-21_48kHz_78_81.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_07-43-54_48kHz_21_24.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_11-05-32_48kHz_51_54.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_13-33-29_48kHz_150_153.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-07_13-33-29_48kHz_153_156.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_09-23-22_48kHz_237_240.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_12-23-09_48kHz_183_186.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_12-35-00_48kHz_285_288.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_12-35-00_48kHz_294_297.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_15-17-57_48kHz_135_138.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_15-46-39_48kHz_45_48.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-08_15-46-39_48kHz_48_51.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09_08-14-52_48kHz_213_216.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09_08-53-34_48kHz_144_147.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09_08-58-34_48kHz_15_18.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09_09-52-16_48kHz_33_36.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09_10-04-45_48kHz_189_192.WAV...
# Exporting ../Dataset/Audios/SEANIMALMOVE/WOPAMDay//Motor_boat/channelA_2024-06-09